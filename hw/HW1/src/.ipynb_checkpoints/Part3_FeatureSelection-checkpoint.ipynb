# %% [markdown]
# # Part 3 Feature Selection
#
#
# ### Goal:
# Use 20%, 30%, 40%, 50%, 60%, 70%, 80%, 90%, and 100% of randomly selecteed features to train the neural network and test on it respectively. You build 9 systems. Plot a graph where the x-axis indicates the percentage of features you used to train a system, and the y-axis indicate the accuracy on the test set of each system

# %%
import warnings 
warnings.filterwarnings('ignore')

import h5py
import numpy as np
import matplotlib.pyplot as plt 

import sklearn 
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.utils import to_categorical
from keras import layers
from keras import models 
from keras.layers import Dense
from keras import optimizers 
from keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
import math

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
def dataCollection(): 
    print("Data Collection")
    wine = sklearn.datasets.load_wine()
    
    df = pd.DataFrame(wine.data)
    df.columns = wine.feature_names
    df["class"] = wine.target
    
    labels = df.loc[:,["class"]] 
    features = df.drop(["class"],axis=1)
    
    return features, labels

# %% [markdown]
# Discussion:
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; While there are various types of feature selection and dimensionalty reduction, I chose to use a type of feature selection called recursive feature elimination (RFE) which works by recursively removing attributes and building a model on those attributes that remain. I chose to use a random forest classifier to identify attributes contribute the most to predicting the labels.
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; The number of features to select by the RFE is determined by multiplying the percentage to the total number of features in the dataset(13)

# %%
def rfe(percentage, features, labels): 
    '''
    Applies recursive feature elimination to find percentage of features to use 
    Returns selected features 
    '''
    print("RFE")
    rfc = RandomForestClassifier(random_state = 101)
    
    # Number of features to select is the percentage given * total features - rounded 
    rfe = RFE(rfc, n_features_to_select = math.floor(percentage*13))
    fit = rfe.fit(features, labels)
    
    print("Number of Features", fit.n_features_)
    print("Ranking of Features", fit.ranking_)
    print("Selected Features", fit.support_)
    
    # selected features from original dataset  
    features = features.loc[:, list(fit.support_)] 
    
    return features

# %%
def dataPrep(features, labels):
    '''
    Prepares features and labels into its respective sets 
    '''
    print("dataPrep")
    xtrain, xtest, ytrain, ytest = train_test_split(features, labels)
    
    #convert labels to categorical 
    ytrain = to_categorical(ytrain, 3)
    ytest = to_categorical(ytest,3)
    
    # Scale data 
    scale = MinMaxScaler(feature_range=(0,1))
    xtrain = scale.fit_transform(xtrain)
    xtest = scale.fit_transform(xtest)
    return xtrain, xtest, ytrain, ytest

# %%
def trainModel(xtrain, ytrain):
    '''
    Builds and runs training model 
    '''
    print("Training the Model")
    
    model = Sequential()
    model.add(Dense(10, input_dim=xtrain.shape[1],activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(4, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    
    model.compile(loss="categorical_crossentropy", optimizer = optimizers.RMSprop(lr = 1e-3), metrics = ["acc"])
    
    # Save weights 
    checkpoint = ModelCheckpoint("model_part3.hdf5", monitor="loss", verbose=1, save_best_only = True, mode="auto", period=1)
    
    # Apply early stopping to prevent overfitting 
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=0, mode='auto',restore_best_weights=True)
    
    # Run Model 
    history = model.fit(xtrain, ytrain, batch_size=50, epochs=2000, verbose =0, validation_split=0.3, callbacks=[checkpoint,monitor])

# %%
def testModel(xtest, ytest): 
    '''
    Builds and runs testing model 
    '''
    print("Testing the model")
    
    evalModel = Sequential()
    evalModel.add(Dense(10, input_dim=xtest.shape[1],activation='relu'))
    evalModel.add(Dense(8, activation='relu'))
    evalModel.add(Dense(6, activation='relu'))
    evalModel.add(Dense(6, activation='relu'))
    evalModel.add(Dense(4, activation='relu'))
    evalModel.add(Dense(3, activation='softmax'))


    evalModel.load_weights('model_part3.hdf5')
    evalModel.compile(loss="categorical_crossentropy", optimizer = optimizers.RMSprop(lr = 1e-3), metrics = ["acc"])
    
    lossAndAcc = evalModel.evaluate(xtest, ytest)

    return lossAndAcc[1]

# %%
def main(percent_features, accuracy): 
    '''
    Driver for program 
    '''
    features, labels = dataCollection()
   
    for i in range(len(percent_features)): 
        print("====================================================")
        print("Percent Features ", percent_features[i])
 
        # Call Recursive Feature Elimation given percent features 
        new_features = rfe(percent_features[i], features, labels)
        
        # Split features and labels 
        xtrain, xtest, ytrain, ytest = dataPrep(new_features, labels)
        
        # Train Model 
        trainModel(xtrain, ytrain)
        
        # Test Model
        curr_acc = testModel(xtest, ytest)
        
        # Add accuracy to our list 
        accuracy.append(curr_acc)
        
        print("====================================================\n")

    
    return accuracy

# %%
percent_features = [0.20, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
accuracy = []

acc = main(percent_features, accuracy)
# Out:
# Data Collection
# ====================================================
# Percent Features  0.2
# RFE
# Number of Features 2
# Ranking of Features [ 4  8 11  9  7  6  1 12 10  1  5  3  2]
# Selected Features [False False False False False False  True False False  True False False
#  False]
# dataPrep
# Training the Model
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Epoch 00001: loss improved from inf to 1.07581, saving model to model_part3.hdf5
#
# Epoch 00002: loss improved from 1.07581 to 1.06799, saving model to model_part3.hdf5
#
# Epoch 00003: loss improved from 1.06799 to 1.06100, saving model to model_part3.hdf5
#
# Epoch 00004: loss improved from 1.06100 to 1.05365, saving model to model_part3.hdf5
#
# Epoch 00005: loss improved from 1.05365 to 1.04691, saving model to model_part3.hdf5
#
# Epoch 00006: loss improved from 1.04691 to 1.04033, saving model to model_part3.hdf5
#
# Epoch 00007: loss improved from 1.04033 to 1.03382, saving model to model_part3.hdf5
#
# Epoch 00008: loss improved from 1.03382 to 1.02790, saving model to model_part3.hdf5
#
# Epoch 00009: loss improved from 1.02790 to 1.02204, saving model to model_part3.hdf5
#
# Epoch 00010: loss improved from 1.02204 to 1.01673, saving model to model_part3.hdf5
#
# Epoch 00011: loss improved from 1.01673 to 1.01137, saving model to model_part3.hdf5
#
# Epoch 00012: loss improved from 1.01137 to 1.00718, saving model to model_part3.hdf5
#
# Epoch 00013: loss improved from 1.00718 to 1.00163, saving model to model_part3.hdf5
#
# Epoch 00014: loss improved from 1.00163 to 0.99677, saving model to model_part3.hdf5
#
# Epoch 00015: loss improved from 0.99677 to 0.99230, saving model to model_part3.hdf5
#
# Epoch 00016: loss improved from 0.99230 to 0.98753, saving model to model_part3.hdf5
#
# Epoch 00017: loss improved from 0.98753 to 0.98350, saving model to model_part3.hdf5
#
# Epoch 00018: loss improved from 0.98350 to 0.97903, saving model to model_part3.hdf5
#
# Epoch 00019: loss improved from 0.97903 to 0.97382, saving model to model_part3.hdf5
#
# Epoch 00020: loss improved from 0.97382 to 0.96958, saving model to model_part3.hdf5
#
# Epoch 00021: loss improved from 0.96958 to 0.96668, saving model to model_part3.hdf5
#
# Epoch 00022: loss improved from 0.96668 to 0.96137, saving model to model_part3.hdf5
#
# Epoch 00023: loss improved from 0.96137 to 0.95713, saving model to model_part3.hdf5
#
# Epoch 00024: loss improved from 0.95713 to 0.95203, saving model to model_part3.hdf5
#
# Epoch 00025: loss improved from 0.95203 to 0.94699, saving model to model_part3.hdf5
#
# Epoch 00026: loss improved from 0.94699 to 0.94313, saving model to model_part3.hdf5
#
# Epoch 00027: loss improved from 0.94313 to 0.93728, saving model to model_part3.hdf5
#
# Epoch 00028: loss improved from 0.93728 to 0.93154, saving model to model_part3.hdf5
#
# Epoch 00029: loss improved from 0.93154 to 0.92577, saving model to model_part3.hdf5
#
# Epoch 00030: loss improved from 0.92577 to 0.92029, saving model to model_part3.hdf5
#
# Epoch 00031: loss improved from 0.92029 to 0.91434, saving model to model_part3.hdf5
#
# Epoch 00032: loss improved from 0.91434 to 0.90851, saving model to model_part3.hdf5
#
# Epoch 00033: loss improved from 0.90851 to 0.90308, saving model to model_part3.hdf5
#
# Epoch 00034: loss improved from 0.90308 to 0.89730, saving model to model_part3.hdf5
#
# Epoch 00035: loss improved from 0.89730 to 0.89173, saving model to model_part3.hdf5
#
# Epoch 00036: loss improved from 0.89173 to 0.88601, saving model to model_part3.hdf5
#
# Epoch 00037: loss improved from 0.88601 to 0.88041, saving model to model_part3.hdf5
#
# Epoch 00038: loss improved from 0.88041 to 0.87492, saving model to model_part3.hdf5
#
# Epoch 00039: loss improved from 0.87492 to 0.86943, saving model to model_part3.hdf5
#
# Epoch 00040: loss improved from 0.86943 to 0.86413, saving model to model_part3.hdf5
#
# Epoch 00041: loss improved from 0.86413 to 0.85875, saving model to model_part3.hdf5
#
# Epoch 00042: loss improved from 0.85875 to 0.85510, saving model to model_part3.hdf5
#
# Epoch 00043: loss improved from 0.85510 to 0.84983, saving model to model_part3.hdf5
#
# Epoch 00044: loss improved from 0.84983 to 0.84443, saving model to model_part3.hdf5
#
# Epoch 00045: loss improved from 0.84443 to 0.83971, saving model to model_part3.hdf5
#
# Epoch 00046: loss improved from 0.83971 to 0.83493, saving model to model_part3.hdf5
#
# Epoch 00047: loss improved from 0.83493 to 0.83061, saving model to model_part3.hdf5
#
# Epoch 00048: loss improved from 0.83061 to 0.82687, saving model to model_part3.hdf5
#
# Epoch 00049: loss improved from 0.82687 to 0.82332, saving model to model_part3.hdf5
#
# Epoch 00050: loss improved from 0.82332 to 0.81762, saving model to model_part3.hdf5
#
# Epoch 00051: loss improved from 0.81762 to 0.81343, saving model to model_part3.hdf5
#
# Epoch 00052: loss improved from 0.81343 to 0.80954, saving model to model_part3.hdf5
#
# Epoch 00053: loss improved from 0.80954 to 0.80520, saving model to model_part3.hdf5
#
# Epoch 00054: loss improved from 0.80520 to 0.80067, saving model to model_part3.hdf5
#
# Epoch 00055: loss improved from 0.80067 to 0.79709, saving model to model_part3.hdf5
#
# Epoch 00056: loss improved from 0.79709 to 0.79375, saving model to model_part3.hdf5
#
# Epoch 00057: loss improved from 0.79375 to 0.78914, saving model to model_part3.hdf5
#
# Epoch 00058: loss improved from 0.78914 to 0.78525, saving model to model_part3.hdf5
#
# Epoch 00059: loss improved from 0.78525 to 0.78324, saving model to model_part3.hdf5
#
# Epoch 00060: loss improved from 0.78324 to 0.78186, saving model to model_part3.hdf5
#
# Epoch 00061: loss improved from 0.78186 to 0.77515, saving model to model_part3.hdf5
#
# Epoch 00062: loss improved from 0.77515 to 0.77094, saving model to model_part3.hdf5
#
# Epoch 00063: loss improved from 0.77094 to 0.76932, saving model to model_part3.hdf5
#
# Epoch 00064: loss improved from 0.76932 to 0.76417, saving model to model_part3.hdf5
#
# Epoch 00065: loss improved from 0.76417 to 0.76061, saving model to model_part3.hdf5
#
# Epoch 00066: loss improved from 0.76061 to 0.75953, saving model to model_part3.hdf5
#
# Epoch 00067: loss improved from 0.75953 to 0.75580, saving model to model_part3.hdf5
#
# Epoch 00068: loss improved from 0.75580 to 0.75072, saving model to model_part3.hdf5
#
# Epoch 00069: loss improved from 0.75072 to 0.74782, saving model to model_part3.hdf5
#
# Epoch 00070: loss improved from 0.74782 to 0.74519, saving model to model_part3.hdf5
#
# Epoch 00071: loss improved from 0.74519 to 0.74132, saving model to model_part3.hdf5
#
# Epoch 00072: loss improved from 0.74132 to 0.73754, saving model to model_part3.hdf5
#
# Epoch 00073: loss improved from 0.73754 to 0.73481, saving model to model_part3.hdf5
#
# Epoch 00074: loss improved from 0.73481 to 0.73063, saving model to model_part3.hdf5
#
# Epoch 00075: loss improved from 0.73063 to 0.72718, saving model to model_part3.hdf5
#
# Epoch 00076: loss improved from 0.72718 to 0.72482, saving model to model_part3.hdf5
#
# Epoch 00077: loss improved from 0.72482 to 0.72028, saving model to model_part3.hdf5
#
# Epoch 00078: loss improved from 0.72028 to 0.71671, saving model to model_part3.hdf5
#
# Epoch 00079: loss improved from 0.71671 to 0.71328, saving model to model_part3.hdf5
#
# Epoch 00080: loss improved from 0.71328 to 0.71090, saving model to model_part3.hdf5
#
# Epoch 00081: loss improved from 0.71090 to 0.70753, saving model to model_part3.hdf5
#
# Epoch 00082: loss improved from 0.70753 to 0.70311, saving model to model_part3.hdf5
#
# Epoch 00083: loss improved from 0.70311 to 0.70074, saving model to model_part3.hdf5
#
# Epoch 00084: loss improved from 0.70074 to 0.69630, saving model to model_part3.hdf5
#
# Epoch 00085: loss improved from 0.69630 to 0.69325, saving model to model_part3.hdf5
#
# Epoch 00086: loss improved from 0.69325 to 0.69034, saving model to model_part3.hdf5
#
# Epoch 00087: loss improved from 0.69034 to 0.68617, saving model to model_part3.hdf5
#
# Epoch 00088: loss improved from 0.68617 to 0.68377, saving model to model_part3.hdf5
#
# Epoch 00089: loss improved from 0.68377 to 0.68081, saving model to model_part3.hdf5
#
# Epoch 00090: loss improved from 0.68081 to 0.67805, saving model to model_part3.hdf5
#
# Epoch 00091: loss improved from 0.67805 to 0.67426, saving model to model_part3.hdf5
#
# Epoch 00092: loss improved from 0.67426 to 0.67029, saving model to model_part3.hdf5
# Epoch 00093: loss improved from 0.67029 to 0.66877, saving model to model_part3.hdf5
#
# Epoch 00094: loss improved from 0.66877 to 0.66367, saving model to model_part3.hdf5
#
# Epoch 00095: loss did not improve from 0.66367
#
# Epoch 00096: loss improved from 0.66367 to 0.65798, saving model to model_part3.hdf5
#
# Epoch 00097: loss improved from 0.65798 to 0.65549, saving model to model_part3.hdf5
#
# Epoch 00098: loss improved from 0.65549 to 0.65155, saving model to model_part3.hdf5
#
# Epoch 00099: loss improved from 0.65155 to 0.64993, saving model to model_part3.hdf5
#
# Epoch 00100: loss improved from 0.64993 to 0.64537, saving model to model_part3.hdf5
#
# Epoch 00101: loss improved from 0.64537 to 0.64424, saving model to model_part3.hdf5
#
# Epoch 00102: loss improved from 0.64424 to 0.63948, saving model to model_part3.hdf5
#
# Epoch 00103: loss improved from 0.63948 to 0.63879, saving model to model_part3.hdf5
#
# Epoch 00104: loss improved from 0.63879 to 0.63420, saving model to model_part3.hdf5
#
# Epoch 00105: loss improved from 0.63420 to 0.63048, saving model to model_part3.hdf5
#
# Epoch 00106: loss improved from 0.63048 to 0.62948, saving model to model_part3.hdf5
#
# Epoch 00107: loss improved from 0.62948 to 0.62613, saving model to model_part3.hdf5
#
# Epoch 00108: loss improved from 0.62613 to 0.62092, saving model to model_part3.hdf5
#
# Epoch 00109: loss improved from 0.62092 to 0.61932, saving model to model_part3.hdf5
#
# Epoch 00110: loss improved from 0.61932 to 0.61540, saving model to model_part3.hdf5
#
# Epoch 00111: loss improved from 0.61540 to 0.61518, saving model to model_part3.hdf5
#
# Epoch 00112: loss improved from 0.61518 to 0.60876, saving model to model_part3.hdf5
#
# Epoch 00113: loss improved from 0.60876 to 0.60550, saving model to model_part3.hdf5
#
# Epoch 00114: loss improved from 0.60550 to 0.60375, saving model to model_part3.hdf5
#
# Epoch 00115: loss improved from 0.60375 to 0.59966, saving model to model_part3.hdf5
#
# Epoch 00116: loss improved from 0.59966 to 0.59633, saving model to model_part3.hdf5
#
# Epoch 00117: loss improved from 0.59633 to 0.59461, saving model to model_part3.hdf5
#
# Epoch 00118: loss improved from 0.59461 to 0.59032, saving model to model_part3.hdf5
#
# Epoch 00119: loss did not improve from 0.59032
#
# Epoch 00120: loss improved from 0.59032 to 0.58417, saving model to model_part3.hdf5
#
# Epoch 00121: loss improved from 0.58417 to 0.58392, saving model to model_part3.hdf5
#
# Epoch 00122: loss improved from 0.58392 to 0.57944, saving model to model_part3.hdf5
#
# Epoch 00123: loss improved from 0.57944 to 0.57498, saving model to model_part3.hdf5
#
# Epoch 00124: loss did not improve from 0.57498
#
# Epoch 00125: loss improved from 0.57498 to 0.56983, saving model to model_part3.hdf5
#
# Epoch 00126: loss improved from 0.56983 to 0.56765, saving model to model_part3.hdf5
#
# Epoch 00127: loss improved from 0.56765 to 0.56504, saving model to model_part3.hdf5
#
# Epoch 00128: loss improved from 0.56504 to 0.56067, saving model to model_part3.hdf5
#
# Epoch 00129: loss improved from 0.56067 to 0.55875, saving model to model_part3.hdf5
#
# Epoch 00130: loss improved from 0.55875 to 0.55526, saving model to model_part3.hdf5
#
# Epoch 00131: loss improved from 0.55526 to 0.55407, saving model to model_part3.hdf5
#
# Epoch 00132: loss improved from 0.55407 to 0.55015, saving model to model_part3.hdf5
#
# Epoch 00133: loss improved from 0.55015 to 0.54657, saving model to model_part3.hdf5
#
# Epoch 00134: loss did not improve from 0.54657
#
# Epoch 00135: loss improved from 0.54657 to 0.54509, saving model to model_part3.hdf5
#
# Epoch 00136: loss improved from 0.54509 to 0.53815, saving model to model_part3.hdf5
#
# Epoch 00137: loss improved from 0.53815 to 0.53665, saving model to model_part3.hdf5
#
# Epoch 00138: loss improved from 0.53665 to 0.53454, saving model to model_part3.hdf5
#
# Epoch 00139: loss improved from 0.53454 to 0.53065, saving model to model_part3.hdf5
#
# Epoch 00140: loss improved from 0.53065 to 0.52903, saving model to model_part3.hdf5
#
# Epoch 00141: loss improved from 0.52903 to 0.52784, saving model to model_part3.hdf5
#
# Epoch 00142: loss improved from 0.52784 to 0.52285, saving model to model_part3.hdf5
#
# Epoch 00143: loss improved from 0.52285 to 0.52029, saving model to model_part3.hdf5
#
# Epoch 00144: loss improved from 0.52029 to 0.51894, saving model to model_part3.hdf5
#
# Epoch 00145: loss improved from 0.51894 to 0.51689, saving model to model_part3.hdf5
#
# Epoch 00146: loss improved from 0.51689 to 0.51606, saving model to model_part3.hdf5
#
# Epoch 00147: loss improved from 0.51606 to 0.51121, saving model to model_part3.hdf5
#
# Epoch 00148: loss improved from 0.51121 to 0.50718, saving model to model_part3.hdf5
#
# Epoch 00149: loss improved from 0.50718 to 0.50563, saving model to model_part3.hdf5
#
# Epoch 00150: loss improved from 0.50563 to 0.50227, saving model to model_part3.hdf5
#
# Epoch 00151: loss improved from 0.50227 to 0.50050, saving model to model_part3.hdf5
#
# Epoch 00152: loss improved from 0.50050 to 0.49869, saving model to model_part3.hdf5
#
# Epoch 00153: loss improved from 0.49869 to 0.49856, saving model to model_part3.hdf5
#
# Epoch 00154: loss improved from 0.49856 to 0.49623, saving model to model_part3.hdf5
#
# Epoch 00155: loss improved from 0.49623 to 0.49152, saving model to model_part3.hdf5
#
# Epoch 00156: loss improved from 0.49152 to 0.49151, saving model to model_part3.hdf5
#
# Epoch 00157: loss improved from 0.49151 to 0.48786, saving model to model_part3.hdf5
#
# Epoch 00158: loss improved from 0.48786 to 0.48745, saving model to model_part3.hdf5
#
# Epoch 00159: loss improved from 0.48745 to 0.48208, saving model to model_part3.hdf5
#
# Epoch 00160: loss improved from 0.48208 to 0.48166, saving model to model_part3.hdf5
#
# Epoch 00161: loss did not improve from 0.48166
#
# Epoch 00162: loss improved from 0.48166 to 0.47833, saving model to model_part3.hdf5
#
# Epoch 00163: loss improved from 0.47833 to 0.47522, saving model to model_part3.hdf5
#
# Epoch 00164: loss improved from 0.47522 to 0.47423, saving model to model_part3.hdf5
#
# Epoch 00165: loss improved from 0.47423 to 0.47301, saving model to model_part3.hdf5
#
# Epoch 00166: loss improved from 0.47301 to 0.46917, saving model to model_part3.hdf5
#
# Epoch 00167: loss did not improve from 0.46917
#
# Epoch 00168: loss improved from 0.46917 to 0.46837, saving model to model_part3.hdf5
#
# Epoch 00169: loss improved from 0.46837 to 0.46312, saving model to model_part3.hdf5
#
# Epoch 00170: loss improved from 0.46312 to 0.46151, saving model to model_part3.hdf5
#
# Epoch 00171: loss improved from 0.46151 to 0.45906, saving model to model_part3.hdf5
#
# Epoch 00172: loss improved from 0.45906 to 0.45674, saving model to model_part3.hdf5
#
# Epoch 00173: loss improved from 0.45674 to 0.45475, saving model to model_part3.hdf5
#
# Epoch 00174: loss did not improve from 0.45475
#
# Epoch 00175: loss improved from 0.45475 to 0.45256, saving model to model_part3.hdf5
#
# Epoch 00176: loss improved from 0.45256 to 0.44859, saving model to model_part3.hdf5
#
# Epoch 00177: loss did not improve from 0.44859
#
# Epoch 00178: loss improved from 0.44859 to 0.44485, saving model to model_part3.hdf5
#
# Epoch 00179: loss did not improve from 0.44485
#
# Epoch 00180: loss did not improve from 0.44485
#
# Epoch 00181: loss improved from 0.44485 to 0.44167, saving model to model_part3.hdf5
#
# Epoch 00182: loss improved from 0.44167 to 0.43848, saving model to model_part3.hdf5
#
# Epoch 00183: loss improved from 0.43848 to 0.43677, saving model to model_part3.hdf5
#
# Epoch 00184: loss improved from 0.43677 to 0.43671, saving model to model_part3.hdf5
#
# Epoch 00185: loss improved from 0.43671 to 0.43452, saving model to model_part3.hdf5
#
# Epoch 00186: loss improved from 0.43452 to 0.43315, saving model to model_part3.hdf5
#
# Epoch 00187: loss did not improve from 0.43315
#
# Epoch 00188: loss improved from 0.43315 to 0.43224, saving model to model_part3.hdf5
#
# Epoch 00189: loss improved from 0.43224 to 0.42659, saving model to model_part3.hdf5
#
# Epoch 00190: loss improved from 0.42659 to 0.42611, saving model to model_part3.hdf5
#
# Epoch 00191: loss did not improve from 0.42611
#
# Epoch 00192: loss improved from 0.42611 to 0.42296, saving model to model_part3.hdf5
#
# Epoch 00193: loss improved from 0.42296 to 0.42076, saving model to model_part3.hdf5
#
# Epoch 00194: loss improved from 0.42076 to 0.41845, saving model to model_part3.hdf5
#
# Epoch 00195: loss improved from 0.41845 to 0.41708, saving model to model_part3.hdf5
#
# Epoch 00196: loss improved from 0.41708 to 0.41607, saving model to model_part3.hdf5
#
# Epoch 00197: loss did not improve from 0.41607
#
# Epoch 00198: loss improved from 0.41607 to 0.41232, saving model to model_part3.hdf5
#
# Epoch 00199: loss did not improve from 0.41232
#
# Epoch 00200: loss improved from 0.41232 to 0.40950, saving model to model_part3.hdf5
#
# Epoch 00201: loss improved from 0.40950 to 0.40751, saving model to model_part3.hdf5
# Epoch 00202: loss improved from 0.40751 to 0.40741, saving model to model_part3.hdf5
#
# Epoch 00203: loss did not improve from 0.40741
#
# Epoch 00204: loss did not improve from 0.40741
# Testing the model
# 45/45 [==============================] - 0s 675us/step
# ====================================================
#
# ====================================================
# Percent Features  0.3
# RFE
# Number of Features 3
# Ranking of Features [ 3  7 10  8  6  5  1 11  9  1  4  2  1]
# Selected Features [False False False False False False  True False False  True False False
#   True]
# dataPrep
# Training the Model
#
# Epoch 00001: loss improved from inf to 1.07191, saving model to model_part3.hdf5
#
# Epoch 00002: loss improved from 1.07191 to 1.06169, saving model to model_part3.hdf5
#
# Epoch 00003: loss improved from 1.06169 to 1.05529, saving model to model_part3.hdf5
#
# Epoch 00004: loss improved from 1.05529 to 1.04852, saving model to model_part3.hdf5
#
# Epoch 00005: loss improved from 1.04852 to 1.04330, saving model to model_part3.hdf5
#
# Epoch 00006: loss improved from 1.04330 to 1.03777, saving model to model_part3.hdf5
#
# Epoch 00007: loss improved from 1.03777 to 1.03288, saving model to model_part3.hdf5
#
# Epoch 00008: loss improved from 1.03288 to 1.02816, saving model to model_part3.hdf5
#
# Epoch 00009: loss improved from 1.02816 to 1.02401, saving model to model_part3.hdf5
#
# Epoch 00010: loss improved from 1.02401 to 1.01975, saving model to model_part3.hdf5
#
# Epoch 00011: loss improved from 1.01975 to 1.01667, saving model to model_part3.hdf5
#
# Epoch 00012: loss improved from 1.01667 to 1.01172, saving model to model_part3.hdf5
#
# Epoch 00013: loss improved from 1.01172 to 1.00791, saving model to model_part3.hdf5
#
# Epoch 00014: loss improved from 1.00791 to 1.00419, saving model to model_part3.hdf5
#
# Epoch 00015: loss improved from 1.00419 to 0.99968, saving model to model_part3.hdf5
#
# Epoch 00016: loss improved from 0.99968 to 0.99547, saving model to model_part3.hdf5
#
# Epoch 00017: loss improved from 0.99547 to 0.99130, saving model to model_part3.hdf5
#
# Epoch 00018: loss improved from 0.99130 to 0.98675, saving model to model_part3.hdf5
#
# Epoch 00019: loss improved from 0.98675 to 0.98218, saving model to model_part3.hdf5
#
# Epoch 00020: loss improved from 0.98218 to 0.97819, saving model to model_part3.hdf5
#
# Epoch 00021: loss improved from 0.97819 to 0.97358, saving model to model_part3.hdf5
#
# Epoch 00022: loss improved from 0.97358 to 0.96824, saving model to model_part3.hdf5
#
# Epoch 00023: loss improved from 0.96824 to 0.96353, saving model to model_part3.hdf5
#
# Epoch 00024: loss improved from 0.96353 to 0.95832, saving model to model_part3.hdf5
#
# Epoch 00025: loss improved from 0.95832 to 0.95320, saving model to model_part3.hdf5
#
# Epoch 00026: loss improved from 0.95320 to 0.94876, saving model to model_part3.hdf5
#
# Epoch 00027: loss improved from 0.94876 to 0.94353, saving model to model_part3.hdf5
#
# Epoch 00028: loss improved from 0.94353 to 0.93867, saving model to model_part3.hdf5
#
# Epoch 00029: loss improved from 0.93867 to 0.93303, saving model to model_part3.hdf5
#
# Epoch 00030: loss improved from 0.93303 to 0.92763, saving model to model_part3.hdf5
#
# Epoch 00031: loss improved from 0.92763 to 0.92311, saving model to model_part3.hdf5
#
# Epoch 00032: loss improved from 0.92311 to 0.91746, saving model to model_part3.hdf5
#
# Epoch 00033: loss improved from 0.91746 to 0.91252, saving model to model_part3.hdf5
#
# Epoch 00034: loss improved from 0.91252 to 0.90721, saving model to model_part3.hdf5
#
# Epoch 00035: loss improved from 0.90721 to 0.90232, saving model to model_part3.hdf5
#
# Epoch 00036: loss improved from 0.90232 to 0.89736, saving model to model_part3.hdf5
#
# Epoch 00037: loss improved from 0.89736 to 0.89279, saving model to model_part3.hdf5
#
# Epoch 00038: loss improved from 0.89279 to 0.88724, saving model to model_part3.hdf5
#
# Epoch 00039: loss improved from 0.88724 to 0.88188, saving model to model_part3.hdf5
#
# Epoch 00040: loss improved from 0.88188 to 0.87771, saving model to model_part3.hdf5
#
# Epoch 00041: loss improved from 0.87771 to 0.87208, saving model to model_part3.hdf5
#
# Epoch 00042: loss improved from 0.87208 to 0.86640, saving model to model_part3.hdf5
#
# Epoch 00043: loss improved from 0.86640 to 0.86138, saving model to model_part3.hdf5
#
# Epoch 00044: loss improved from 0.86138 to 0.85636, saving model to model_part3.hdf5
#
# Epoch 00045: loss improved from 0.85636 to 0.85256, saving model to model_part3.hdf5
#
# Epoch 00046: loss improved from 0.85256 to 0.84794, saving model to model_part3.hdf5
#
# Epoch 00047: loss improved from 0.84794 to 0.84236, saving model to model_part3.hdf5
#
# Epoch 00048: loss improved from 0.84236 to 0.83773, saving model to model_part3.hdf5
#
# Epoch 00049: loss improved from 0.83773 to 0.83228, saving model to model_part3.hdf5
#
# Epoch 00050: loss improved from 0.83228 to 0.82762, saving model to model_part3.hdf5
#
# Epoch 00051: loss improved from 0.82762 to 0.82277, saving model to model_part3.hdf5
#
# Epoch 00052: loss improved from 0.82277 to 0.81801, saving model to model_part3.hdf5
#
# Epoch 00053: loss improved from 0.81801 to 0.81369, saving model to model_part3.hdf5
#
# Epoch 00054: loss improved from 0.81369 to 0.80933, saving model to model_part3.hdf5
#
# Epoch 00055: loss improved from 0.80933 to 0.80370, saving model to model_part3.hdf5
#
# Epoch 00056: loss improved from 0.80370 to 0.79941, saving model to model_part3.hdf5
#
# Epoch 00057: loss improved from 0.79941 to 0.79425, saving model to model_part3.hdf5
#
# Epoch 00058: loss improved from 0.79425 to 0.78963, saving model to model_part3.hdf5
#
# Epoch 00059: loss improved from 0.78963 to 0.78474, saving model to model_part3.hdf5
#
# Epoch 00060: loss improved from 0.78474 to 0.78049, saving model to model_part3.hdf5
#
# Epoch 00061: loss improved from 0.78049 to 0.77550, saving model to model_part3.hdf5
#
# Epoch 00062: loss improved from 0.77550 to 0.76996, saving model to model_part3.hdf5
#
# Epoch 00063: loss improved from 0.76996 to 0.76585, saving model to model_part3.hdf5
#
# Epoch 00064: loss improved from 0.76585 to 0.76127, saving model to model_part3.hdf5
#
# Epoch 00065: loss improved from 0.76127 to 0.75653, saving model to model_part3.hdf5
#
# Epoch 00066: loss improved from 0.75653 to 0.75186, saving model to model_part3.hdf5
#
# Epoch 00067: loss improved from 0.75186 to 0.74744, saving model to model_part3.hdf5
#
# Epoch 00068: loss improved from 0.74744 to 0.74190, saving model to model_part3.hdf5
#
# Epoch 00069: loss improved from 0.74190 to 0.73714, saving model to model_part3.hdf5
#
# Epoch 00070: loss improved from 0.73714 to 0.73143, saving model to model_part3.hdf5
#
# Epoch 00071: loss improved from 0.73143 to 0.72591, saving model to model_part3.hdf5
#
# Epoch 00072: loss improved from 0.72591 to 0.72056, saving model to model_part3.hdf5
#
# Epoch 00073: loss improved from 0.72056 to 0.71597, saving model to model_part3.hdf5
#
# Epoch 00074: loss improved from 0.71597 to 0.70970, saving model to model_part3.hdf5
#
# Epoch 00075: loss improved from 0.70970 to 0.70490, saving model to model_part3.hdf5
#
# Epoch 00076: loss improved from 0.70490 to 0.69955, saving model to model_part3.hdf5
#
# Epoch 00077: loss improved from 0.69955 to 0.69436, saving model to model_part3.hdf5
#
# Epoch 00078: loss improved from 0.69436 to 0.68982, saving model to model_part3.hdf5
#
# Epoch 00079: loss improved from 0.68982 to 0.68357, saving model to model_part3.hdf5
#
# Epoch 00080: loss improved from 0.68357 to 0.67827, saving model to model_part3.hdf5
#
# Epoch 00081: loss improved from 0.67827 to 0.67366, saving model to model_part3.hdf5
#
# Epoch 00082: loss improved from 0.67366 to 0.66739, saving model to model_part3.hdf5
#
# Epoch 00083: loss improved from 0.66739 to 0.66196, saving model to model_part3.hdf5
#
# Epoch 00084: loss improved from 0.66196 to 0.65630, saving model to model_part3.hdf5
#
# Epoch 00085: loss improved from 0.65630 to 0.65058, saving model to model_part3.hdf5
#
# Epoch 00086: loss improved from 0.65058 to 0.64501, saving model to model_part3.hdf5
#
# Epoch 00087: loss improved from 0.64501 to 0.63858, saving model to model_part3.hdf5
#
# Epoch 00088: loss improved from 0.63858 to 0.63263, saving model to model_part3.hdf5
#
# Epoch 00089: loss improved from 0.63263 to 0.62559, saving model to model_part3.hdf5
#
# Epoch 00090: loss improved from 0.62559 to 0.62014, saving model to model_part3.hdf5
#
# Epoch 00091: loss improved from 0.62014 to 0.61292, saving model to model_part3.hdf5
#
# Epoch 00092: loss improved from 0.61292 to 0.60762, saving model to model_part3.hdf5
#
# Epoch 00093: loss improved from 0.60762 to 0.60016, saving model to model_part3.hdf5
# Epoch 00094: loss improved from 0.60016 to 0.59421, saving model to model_part3.hdf5
#
# Epoch 00095: loss improved from 0.59421 to 0.58853, saving model to model_part3.hdf5
#
# Epoch 00096: loss improved from 0.58853 to 0.58176, saving model to model_part3.hdf5
#
# Epoch 00097: loss improved from 0.58176 to 0.57618, saving model to model_part3.hdf5
#
# Epoch 00098: loss improved from 0.57618 to 0.57013, saving model to model_part3.hdf5
#
# Epoch 00099: loss improved from 0.57013 to 0.56360, saving model to model_part3.hdf5
#
# Epoch 00100: loss improved from 0.56360 to 0.55787, saving model to model_part3.hdf5
#
# Epoch 00101: loss improved from 0.55787 to 0.55274, saving model to model_part3.hdf5
#
# Epoch 00102: loss improved from 0.55274 to 0.54591, saving model to model_part3.hdf5
#
# Epoch 00103: loss improved from 0.54591 to 0.54005, saving model to model_part3.hdf5
#
# Epoch 00104: loss improved from 0.54005 to 0.53368, saving model to model_part3.hdf5
#
# Epoch 00105: loss improved from 0.53368 to 0.52820, saving model to model_part3.hdf5
#
# Epoch 00106: loss improved from 0.52820 to 0.52195, saving model to model_part3.hdf5
#
# Epoch 00107: loss improved from 0.52195 to 0.51609, saving model to model_part3.hdf5
#
# Epoch 00108: loss improved from 0.51609 to 0.50971, saving model to model_part3.hdf5
#
# Epoch 00109: loss improved from 0.50971 to 0.50392, saving model to model_part3.hdf5
#
# Epoch 00110: loss improved from 0.50392 to 0.49828, saving model to model_part3.hdf5
#
# Epoch 00111: loss improved from 0.49828 to 0.49244, saving model to model_part3.hdf5
#
# Epoch 00112: loss improved from 0.49244 to 0.48725, saving model to model_part3.hdf5
#
# Epoch 00113: loss improved from 0.48725 to 0.48301, saving model to model_part3.hdf5
#
# Epoch 00114: loss improved from 0.48301 to 0.47614, saving model to model_part3.hdf5
#
# Epoch 00115: loss improved from 0.47614 to 0.47089, saving model to model_part3.hdf5
#
# Epoch 00116: loss improved from 0.47089 to 0.46898, saving model to model_part3.hdf5
#
# Epoch 00117: loss improved from 0.46898 to 0.46152, saving model to model_part3.hdf5
#
# Epoch 00118: loss improved from 0.46152 to 0.45767, saving model to model_part3.hdf5
#
# Epoch 00119: loss improved from 0.45767 to 0.45421, saving model to model_part3.hdf5
#
# Epoch 00120: loss improved from 0.45421 to 0.44966, saving model to model_part3.hdf5
#
# Epoch 00121: loss improved from 0.44966 to 0.44389, saving model to model_part3.hdf5
#
# Epoch 00122: loss improved from 0.44389 to 0.43965, saving model to model_part3.hdf5
#
# Epoch 00123: loss improved from 0.43965 to 0.43609, saving model to model_part3.hdf5
#
# Epoch 00124: loss improved from 0.43609 to 0.43207, saving model to model_part3.hdf5
#
# Epoch 00125: loss improved from 0.43207 to 0.42906, saving model to model_part3.hdf5
#
# Epoch 00126: loss improved from 0.42906 to 0.42476, saving model to model_part3.hdf5
#
# Epoch 00127: loss improved from 0.42476 to 0.42001, saving model to model_part3.hdf5
#
# Epoch 00128: loss improved from 0.42001 to 0.41543, saving model to model_part3.hdf5
#
# Epoch 00129: loss improved from 0.41543 to 0.41337, saving model to model_part3.hdf5
#
# Epoch 00130: loss improved from 0.41337 to 0.40791, saving model to model_part3.hdf5
#
# Epoch 00131: loss did not improve from 0.40791
#
# Epoch 00132: loss improved from 0.40791 to 0.40085, saving model to model_part3.hdf5
#
# Epoch 00133: loss improved from 0.40085 to 0.39865, saving model to model_part3.hdf5
#
# Epoch 00134: loss improved from 0.39865 to 0.39636, saving model to model_part3.hdf5
#
# Epoch 00135: loss improved from 0.39636 to 0.39123, saving model to model_part3.hdf5
#
# Epoch 00136: loss improved from 0.39123 to 0.38783, saving model to model_part3.hdf5
#
# Epoch 00137: loss improved from 0.38783 to 0.38485, saving model to model_part3.hdf5
#
# Epoch 00138: loss improved from 0.38485 to 0.38295, saving model to model_part3.hdf5
#
# Epoch 00139: loss improved from 0.38295 to 0.37954, saving model to model_part3.hdf5
#
# Epoch 00140: loss improved from 0.37954 to 0.37569, saving model to model_part3.hdf5
#
# Epoch 00141: loss improved from 0.37569 to 0.37319, saving model to model_part3.hdf5
#
# Epoch 00142: loss improved from 0.37319 to 0.36891, saving model to model_part3.hdf5
#
# Epoch 00143: loss improved from 0.36891 to 0.36604, saving model to model_part3.hdf5
#
# Epoch 00144: loss improved from 0.36604 to 0.36273, saving model to model_part3.hdf5
#
# Epoch 00145: loss improved from 0.36273 to 0.36037, saving model to model_part3.hdf5
#
# Epoch 00146: loss improved from 0.36037 to 0.35808, saving model to model_part3.hdf5
#
# Epoch 00147: loss improved from 0.35808 to 0.35388, saving model to model_part3.hdf5
#
# Epoch 00148: loss improved from 0.35388 to 0.35252, saving model to model_part3.hdf5
#
# Epoch 00149: loss improved from 0.35252 to 0.35009, saving model to model_part3.hdf5
#
# Epoch 00150: loss improved from 0.35009 to 0.34871, saving model to model_part3.hdf5
#
# Epoch 00151: loss improved from 0.34871 to 0.34381, saving model to model_part3.hdf5
#
# Epoch 00152: loss improved from 0.34381 to 0.34297, saving model to model_part3.hdf5
#
# Epoch 00153: loss improved from 0.34297 to 0.33876, saving model to model_part3.hdf5
#
# Epoch 00154: loss improved from 0.33876 to 0.33630, saving model to model_part3.hdf5
#
# Epoch 00155: loss improved from 0.33630 to 0.33382, saving model to model_part3.hdf5
#
# Epoch 00156: loss improved from 0.33382 to 0.33218, saving model to model_part3.hdf5
#
# Epoch 00157: loss improved from 0.33218 to 0.32945, saving model to model_part3.hdf5
#
# Epoch 00158: loss did not improve from 0.32945
#
# Epoch 00159: loss improved from 0.32945 to 0.32507, saving model to model_part3.hdf5
#
# Epoch 00160: loss improved from 0.32507 to 0.32395, saving model to model_part3.hdf5
#
# Epoch 00161: loss improved from 0.32395 to 0.32126, saving model to model_part3.hdf5
#
# Epoch 00162: loss improved from 0.32126 to 0.31910, saving model to model_part3.hdf5
#
# Epoch 00163: loss improved from 0.31910 to 0.31688, saving model to model_part3.hdf5
#
# Epoch 00164: loss improved from 0.31688 to 0.31533, saving model to model_part3.hdf5
#
# Epoch 00165: loss improved from 0.31533 to 0.31291, saving model to model_part3.hdf5
#
# Epoch 00166: loss improved from 0.31291 to 0.31263, saving model to model_part3.hdf5
#
# Epoch 00167: loss improved from 0.31263 to 0.30877, saving model to model_part3.hdf5
#
# Epoch 00168: loss improved from 0.30877 to 0.30670, saving model to model_part3.hdf5
#
# Epoch 00169: loss improved from 0.30670 to 0.30472, saving model to model_part3.hdf5
#
# Epoch 00170: loss did not improve from 0.30472
#
# Epoch 00171: loss improved from 0.30472 to 0.30151, saving model to model_part3.hdf5
#
# Epoch 00172: loss did not improve from 0.30151
#
# Epoch 00173: loss improved from 0.30151 to 0.29913, saving model to model_part3.hdf5
#
# Epoch 00174: loss improved from 0.29913 to 0.29830, saving model to model_part3.hdf5
#
# Epoch 00175: loss improved from 0.29830 to 0.29761, saving model to model_part3.hdf5
# Testing the model
# 45/45 [==============================] - 0s 1ms/step
# ====================================================
#
# ====================================================
# Percent Features  0.4
# RFE
# Number of Features 5
# Ranking of Features [1 5 8 6 4 3 1 9 7 1 2 1 1]
# Selected Features [ True False False False False False  True False False  True False  True
#   True]
# dataPrep
# Training the Model
#
# Epoch 00001: loss improved from inf to 1.10313, saving model to model_part3.hdf5
#
# Epoch 00002: loss improved from 1.10313 to 1.09850, saving model to model_part3.hdf5
#
# Epoch 00003: loss improved from 1.09850 to 1.09669, saving model to model_part3.hdf5
#
# Epoch 00004: loss improved from 1.09669 to 1.09571, saving model to model_part3.hdf5
#
# Epoch 00005: loss improved from 1.09571 to 1.09475, saving model to model_part3.hdf5
#
# Epoch 00006: loss improved from 1.09475 to 1.09392, saving model to model_part3.hdf5
#
# Epoch 00007: loss improved from 1.09392 to 1.09308, saving model to model_part3.hdf5
#
# Epoch 00008: loss improved from 1.09308 to 1.09231, saving model to model_part3.hdf5
#
# Epoch 00009: loss improved from 1.09231 to 1.09142, saving model to model_part3.hdf5
#
# Epoch 00010: loss improved from 1.09142 to 1.09056, saving model to model_part3.hdf5
#
# Epoch 00011: loss improved from 1.09056 to 1.08975, saving model to model_part3.hdf5
#
# Epoch 00012: loss improved from 1.08975 to 1.08876, saving model to model_part3.hdf5
#
# Epoch 00013: loss improved from 1.08876 to 1.08840, saving model to model_part3.hdf5
#
# Epoch 00014: loss improved from 1.08840 to 1.08737, saving model to model_part3.hdf5
#
# Epoch 00015: loss improved from 1.08737 to 1.08645, saving model to model_part3.hdf5
# Epoch 00016: loss improved from 1.08645 to 1.08551, saving model to model_part3.hdf5
#
# Epoch 00017: loss improved from 1.08551 to 1.08465, saving model to model_part3.hdf5
#
# Epoch 00018: loss improved from 1.08465 to 1.08406, saving model to model_part3.hdf5
#
# Epoch 00019: loss improved from 1.08406 to 1.08287, saving model to model_part3.hdf5
#
# Epoch 00020: loss improved from 1.08287 to 1.08203, saving model to model_part3.hdf5
#
# Epoch 00021: loss improved from 1.08203 to 1.08075, saving model to model_part3.hdf5
#
# Epoch 00022: loss improved from 1.08075 to 1.07985, saving model to model_part3.hdf5
#
# Epoch 00023: loss improved from 1.07985 to 1.07846, saving model to model_part3.hdf5
#
# Epoch 00024: loss improved from 1.07846 to 1.07720, saving model to model_part3.hdf5
#
# Epoch 00025: loss improved from 1.07720 to 1.07603, saving model to model_part3.hdf5
#
# Epoch 00026: loss improved from 1.07603 to 1.07482, saving model to model_part3.hdf5
#
# Epoch 00027: loss improved from 1.07482 to 1.07390, saving model to model_part3.hdf5
#
# Epoch 00028: loss improved from 1.07390 to 1.07214, saving model to model_part3.hdf5
#
# Epoch 00029: loss improved from 1.07214 to 1.07078, saving model to model_part3.hdf5
#
# Epoch 00030: loss improved from 1.07078 to 1.06907, saving model to model_part3.hdf5
#
# Epoch 00031: loss improved from 1.06907 to 1.06712, saving model to model_part3.hdf5
#
# Epoch 00032: loss improved from 1.06712 to 1.06501, saving model to model_part3.hdf5
#
# Epoch 00033: loss improved from 1.06501 to 1.06275, saving model to model_part3.hdf5
#
# Epoch 00034: loss improved from 1.06275 to 1.06026, saving model to model_part3.hdf5
#
# Epoch 00035: loss improved from 1.06026 to 1.05773, saving model to model_part3.hdf5
#
# Epoch 00036: loss improved from 1.05773 to 1.05538, saving model to model_part3.hdf5
#
# Epoch 00037: loss improved from 1.05538 to 1.05203, saving model to model_part3.hdf5
#
# Epoch 00038: loss improved from 1.05203 to 1.04903, saving model to model_part3.hdf5
#
# Epoch 00039: loss improved from 1.04903 to 1.04624, saving model to model_part3.hdf5
#
# Epoch 00040: loss improved from 1.04624 to 1.04317, saving model to model_part3.hdf5
#
# Epoch 00041: loss improved from 1.04317 to 1.04001, saving model to model_part3.hdf5
#
# Epoch 00042: loss improved from 1.04001 to 1.03694, saving model to model_part3.hdf5
#
# Epoch 00043: loss improved from 1.03694 to 1.03388, saving model to model_part3.hdf5
#
# Epoch 00044: loss improved from 1.03388 to 1.03076, saving model to model_part3.hdf5
#
# Epoch 00045: loss improved from 1.03076 to 1.02743, saving model to model_part3.hdf5
#
# Epoch 00046: loss improved from 1.02743 to 1.02413, saving model to model_part3.hdf5
#
# Epoch 00047: loss improved from 1.02413 to 1.02069, saving model to model_part3.hdf5
#
# Epoch 00048: loss improved from 1.02069 to 1.01734, saving model to model_part3.hdf5
#
# Epoch 00049: loss improved from 1.01734 to 1.01398, saving model to model_part3.hdf5
#
# Epoch 00050: loss improved from 1.01398 to 1.01016, saving model to model_part3.hdf5
#
# Epoch 00051: loss improved from 1.01016 to 1.00653, saving model to model_part3.hdf5
#
# Epoch 00052: loss improved from 1.00653 to 1.00275, saving model to model_part3.hdf5
#
# Epoch 00053: loss improved from 1.00275 to 0.99928, saving model to model_part3.hdf5
#
# Epoch 00054: loss improved from 0.99928 to 0.99527, saving model to model_part3.hdf5
#
# Epoch 00055: loss improved from 0.99527 to 0.99137, saving model to model_part3.hdf5
#
# Epoch 00056: loss improved from 0.99137 to 0.98736, saving model to model_part3.hdf5
#
# Epoch 00057: loss improved from 0.98736 to 0.98325, saving model to model_part3.hdf5
#
# Epoch 00058: loss improved from 0.98325 to 0.97930, saving model to model_part3.hdf5
#
# Epoch 00059: loss improved from 0.97930 to 0.97507, saving model to model_part3.hdf5
#
# Epoch 00060: loss improved from 0.97507 to 0.97134, saving model to model_part3.hdf5
#
# Epoch 00061: loss improved from 0.97134 to 0.96702, saving model to model_part3.hdf5
#
# Epoch 00062: loss improved from 0.96702 to 0.96271, saving model to model_part3.hdf5
#
# Epoch 00063: loss improved from 0.96271 to 0.95852, saving model to model_part3.hdf5
#
# Epoch 00064: loss improved from 0.95852 to 0.95465, saving model to model_part3.hdf5
#
# Epoch 00065: loss improved from 0.95465 to 0.95005, saving model to model_part3.hdf5
#
# Epoch 00066: loss improved from 0.95005 to 0.94566, saving model to model_part3.hdf5
#
# Epoch 00067: loss improved from 0.94566 to 0.94205, saving model to model_part3.hdf5
#
# Epoch 00068: loss improved from 0.94205 to 0.93757, saving model to model_part3.hdf5
#
# Epoch 00069: loss improved from 0.93757 to 0.93322, saving model to model_part3.hdf5
#
# Epoch 00070: loss improved from 0.93322 to 0.92880, saving model to model_part3.hdf5
#
# Epoch 00071: loss improved from 0.92880 to 0.92505, saving model to model_part3.hdf5
#
# Epoch 00072: loss improved from 0.92505 to 0.92041, saving model to model_part3.hdf5
#
# Epoch 00073: loss improved from 0.92041 to 0.91620, saving model to model_part3.hdf5
#
# Epoch 00074: loss improved from 0.91620 to 0.91191, saving model to model_part3.hdf5
#
# Epoch 00075: loss improved from 0.91191 to 0.90796, saving model to model_part3.hdf5
#
# Epoch 00076: loss improved from 0.90796 to 0.90337, saving model to model_part3.hdf5
#
# Epoch 00077: loss improved from 0.90337 to 0.89882, saving model to model_part3.hdf5
#
# Epoch 00078: loss improved from 0.89882 to 0.89524, saving model to model_part3.hdf5
#
# Epoch 00079: loss improved from 0.89524 to 0.89100, saving model to model_part3.hdf5
#
# Epoch 00080: loss improved from 0.89100 to 0.88682, saving model to model_part3.hdf5
#
# Epoch 00081: loss improved from 0.88682 to 0.88238, saving model to model_part3.hdf5
#
# Epoch 00082: loss improved from 0.88238 to 0.87872, saving model to model_part3.hdf5
#
# Epoch 00083: loss improved from 0.87872 to 0.87441, saving model to model_part3.hdf5
#
# Epoch 00084: loss improved from 0.87441 to 0.87034, saving model to model_part3.hdf5
#
# Epoch 00085: loss improved from 0.87034 to 0.86663, saving model to model_part3.hdf5
#
# Epoch 00086: loss improved from 0.86663 to 0.86208, saving model to model_part3.hdf5
#
# Epoch 00087: loss improved from 0.86208 to 0.85806, saving model to model_part3.hdf5
#
# Epoch 00088: loss improved from 0.85806 to 0.85402, saving model to model_part3.hdf5
#
# Epoch 00089: loss improved from 0.85402 to 0.85004, saving model to model_part3.hdf5
#
# Epoch 00090: loss improved from 0.85004 to 0.84627, saving model to model_part3.hdf5
#
# Epoch 00091: loss improved from 0.84627 to 0.84231, saving model to model_part3.hdf5
#
# Epoch 00092: loss improved from 0.84231 to 0.83832, saving model to model_part3.hdf5
#
# Epoch 00093: loss improved from 0.83832 to 0.83481, saving model to model_part3.hdf5
#
# Epoch 00094: loss improved from 0.83481 to 0.83094, saving model to model_part3.hdf5
#
# Epoch 00095: loss improved from 0.83094 to 0.82730, saving model to model_part3.hdf5
#
# Epoch 00096: loss improved from 0.82730 to 0.82375, saving model to model_part3.hdf5
#
# Epoch 00097: loss improved from 0.82375 to 0.82021, saving model to model_part3.hdf5
#
# Epoch 00098: loss improved from 0.82021 to 0.81680, saving model to model_part3.hdf5
#
# Epoch 00099: loss improved from 0.81680 to 0.81361, saving model to model_part3.hdf5
#
# Epoch 00100: loss improved from 0.81361 to 0.81101, saving model to model_part3.hdf5
#
# Epoch 00101: loss improved from 0.81101 to 0.80745, saving model to model_part3.hdf5
#
# Epoch 00102: loss improved from 0.80745 to 0.80459, saving model to model_part3.hdf5
#
# Epoch 00103: loss improved from 0.80459 to 0.80161, saving model to model_part3.hdf5
#
# Epoch 00104: loss improved from 0.80161 to 0.79868, saving model to model_part3.hdf5
#
# Epoch 00105: loss improved from 0.79868 to 0.79612, saving model to model_part3.hdf5
#
# Epoch 00106: loss improved from 0.79612 to 0.79313, saving model to model_part3.hdf5
#
# Epoch 00107: loss improved from 0.79313 to 0.79140, saving model to model_part3.hdf5
#
# Epoch 00108: loss improved from 0.79140 to 0.78783, saving model to model_part3.hdf5
#
# Epoch 00109: loss improved from 0.78783 to 0.78540, saving model to model_part3.hdf5
#
# Epoch 00110: loss improved from 0.78540 to 0.78275, saving model to model_part3.hdf5
#
# Epoch 00111: loss improved from 0.78275 to 0.78027, saving model to model_part3.hdf5
#
# Epoch 00112: loss improved from 0.78027 to 0.77745, saving model to model_part3.hdf5
# Epoch 00113: loss improved from 0.77745 to 0.77617, saving model to model_part3.hdf5
#
# Epoch 00114: loss improved from 0.77617 to 0.77351, saving model to model_part3.hdf5
#
# Epoch 00115: loss improved from 0.77351 to 0.77063, saving model to model_part3.hdf5
#
# Epoch 00116: loss improved from 0.77063 to 0.76849, saving model to model_part3.hdf5
#
# Epoch 00117: loss did not improve from 0.76849
#
# Epoch 00118: loss improved from 0.76849 to 0.76544, saving model to model_part3.hdf5
#
# Epoch 00119: loss improved from 0.76544 to 0.76297, saving model to model_part3.hdf5
#
# Epoch 00120: loss improved from 0.76297 to 0.76128, saving model to model_part3.hdf5
#
# Epoch 00121: loss improved from 0.76128 to 0.75996, saving model to model_part3.hdf5
#
# Epoch 00122: loss improved from 0.75996 to 0.75804, saving model to model_part3.hdf5
#
# Epoch 00123: loss improved from 0.75804 to 0.75643, saving model to model_part3.hdf5
#
# Epoch 00124: loss improved from 0.75643 to 0.75456, saving model to model_part3.hdf5
#
# Epoch 00125: loss improved from 0.75456 to 0.75368, saving model to model_part3.hdf5
#
# Epoch 00126: loss improved from 0.75368 to 0.75294, saving model to model_part3.hdf5
#
# Epoch 00127: loss improved from 0.75294 to 0.75169, saving model to model_part3.hdf5
#
# Epoch 00128: loss improved from 0.75169 to 0.74869, saving model to model_part3.hdf5
#
# Epoch 00129: loss improved from 0.74869 to 0.74723, saving model to model_part3.hdf5
#
# Epoch 00130: loss improved from 0.74723 to 0.74615, saving model to model_part3.hdf5
#
# Epoch 00131: loss improved from 0.74615 to 0.74540, saving model to model_part3.hdf5
#
# Epoch 00132: loss improved from 0.74540 to 0.74397, saving model to model_part3.hdf5
#
# Epoch 00133: loss improved from 0.74397 to 0.74230, saving model to model_part3.hdf5
#
# Epoch 00134: loss improved from 0.74230 to 0.74115, saving model to model_part3.hdf5
#
# Epoch 00135: loss improved from 0.74115 to 0.74002, saving model to model_part3.hdf5
#
# Epoch 00136: loss improved from 0.74002 to 0.73946, saving model to model_part3.hdf5
#
# Epoch 00137: loss improved from 0.73946 to 0.73769, saving model to model_part3.hdf5
#
# Epoch 00138: loss improved from 0.73769 to 0.73649, saving model to model_part3.hdf5
#
# Epoch 00139: loss improved from 0.73649 to 0.73501, saving model to model_part3.hdf5
#
# Epoch 00140: loss did not improve from 0.73501
#
# Epoch 00141: loss improved from 0.73501 to 0.73285, saving model to model_part3.hdf5
#
# Epoch 00142: loss improved from 0.73285 to 0.73171, saving model to model_part3.hdf5
#
# Epoch 00143: loss improved from 0.73171 to 0.73081, saving model to model_part3.hdf5
#
# Epoch 00144: loss improved from 0.73081 to 0.72999, saving model to model_part3.hdf5
#
# Epoch 00145: loss improved from 0.72999 to 0.72907, saving model to model_part3.hdf5
#
# Epoch 00146: loss improved from 0.72907 to 0.72741, saving model to model_part3.hdf5
#
# Epoch 00147: loss improved from 0.72741 to 0.72657, saving model to model_part3.hdf5
#
# Epoch 00148: loss improved from 0.72657 to 0.72631, saving model to model_part3.hdf5
#
# Epoch 00149: loss improved from 0.72631 to 0.72443, saving model to model_part3.hdf5
#
# Epoch 00150: loss improved from 0.72443 to 0.72357, saving model to model_part3.hdf5
#
# Epoch 00151: loss improved from 0.72357 to 0.72266, saving model to model_part3.hdf5
#
# Epoch 00152: loss improved from 0.72266 to 0.72130, saving model to model_part3.hdf5
#
# Epoch 00153: loss improved from 0.72130 to 0.72006, saving model to model_part3.hdf5
#
# Epoch 00154: loss improved from 0.72006 to 0.71920, saving model to model_part3.hdf5
#
# Epoch 00155: loss did not improve from 0.71920
#
# Epoch 00156: loss improved from 0.71920 to 0.71744, saving model to model_part3.hdf5
#
# Epoch 00157: loss did not improve from 0.71744
#
# Epoch 00158: loss improved from 0.71744 to 0.71517, saving model to model_part3.hdf5
#
# Epoch 00159: loss improved from 0.71517 to 0.71436, saving model to model_part3.hdf5
#
# Epoch 00160: loss improved from 0.71436 to 0.71435, saving model to model_part3.hdf5
#
# Epoch 00161: loss improved from 0.71435 to 0.71237, saving model to model_part3.hdf5
#
# Epoch 00162: loss improved from 0.71237 to 0.71171, saving model to model_part3.hdf5
#
# Epoch 00163: loss improved from 0.71171 to 0.71131, saving model to model_part3.hdf5
#
# Epoch 00164: loss improved from 0.71131 to 0.70958, saving model to model_part3.hdf5
#
# Epoch 00165: loss improved from 0.70958 to 0.70899, saving model to model_part3.hdf5
#
# Epoch 00166: loss improved from 0.70899 to 0.70861, saving model to model_part3.hdf5
#
# Epoch 00167: loss improved from 0.70861 to 0.70709, saving model to model_part3.hdf5
#
# Epoch 00168: loss improved from 0.70709 to 0.70657, saving model to model_part3.hdf5
#
# Epoch 00169: loss improved from 0.70657 to 0.70528, saving model to model_part3.hdf5
#
# Epoch 00170: loss improved from 0.70528 to 0.70503, saving model to model_part3.hdf5
#
# ...
#
# Epoch 00097: loss improved from 0.69201 to 0.68893, saving model to model_part3.hdf5
#
# Epoch 00098: loss improved from 0.68893 to 0.68431, saving model to model_part3.hdf5
#
# Epoch 00099: loss improved from 0.68431 to 0.68092, saving model to model_part3.hdf5
#
# Epoch 00100: loss improved from 0.68092 to 0.67815, saving model to model_part3.hdf5
#
# Epoch 00101: loss improved from 0.67815 to 0.67598, saving model to model_part3.hdf5
#
# Epoch 00102: loss improved from 0.67598 to 0.67480, saving model to model_part3.hdf5
#
# Epoch 00103: loss improved from 0.67480 to 0.67238, saving model to model_part3.hdf5
#
# Epoch 00104: loss improved from 0.67238 to 0.66536, saving model to model_part3.hdf5
#
# Epoch 00105: loss improved from 0.66536 to 0.66227, saving model to model_part3.hdf5
#
# Epoch 00106: loss improved from 0.66227 to 0.65888, saving model to model_part3.hdf5
#
# Epoch 00107: loss improved from 0.65888 to 0.65760, saving model to model_part3.hdf5
#
# Epoch 00108: loss improved from 0.65760 to 0.65344, saving model to model_part3.hdf5
#
# Epoch 00109: loss improved from 0.65344 to 0.64968, saving model to model_part3.hdf5
#
# Epoch 00110: loss improved from 0.64968 to 0.64586, saving model to model_part3.hdf5
#
# Epoch 00111: loss improved from 0.64586 to 0.64392, saving model to model_part3.hdf5
#
# Epoch 00112: loss improved from 0.64392 to 0.63920, saving model to model_part3.hdf5
#
# Epoch 00113: loss improved from 0.63920 to 0.63510, saving model to model_part3.hdf5
#
# Epoch 00114: loss improved from 0.63510 to 0.63203, saving model to model_part3.hdf5
#
# Epoch 00115: loss improved from 0.63203 to 0.62752, saving model to model_part3.hdf5
#
# Epoch 00116: loss improved from 0.62752 to 0.62379, saving model to model_part3.hdf5
#
# Epoch 00117: loss improved from 0.62379 to 0.62141, saving model to model_part3.hdf5
#
# Epoch 00118: loss improved from 0.62141 to 0.61548, saving model to model_part3.hdf5
#
# Epoch 00119: loss improved from 0.61548 to 0.61135, saving model to model_part3.hdf5
#
# Epoch 00120: loss improved from 0.61135 to 0.60710, saving model to model_part3.hdf5
#
# Epoch 00121: loss improved from 0.60710 to 0.60323, saving model to model_part3.hdf5
#
# Epoch 00122: loss improved from 0.60323 to 0.59894, saving model to model_part3.hdf5
#
# Epoch 00123: loss improved from 0.59894 to 0.59794, saving model to model_part3.hdf5
#
# Epoch 00124: loss improved from 0.59794 to 0.59177, saving model to model_part3.hdf5
#
# Epoch 00125: loss improved from 0.59177 to 0.58646, saving model to model_part3.hdf5
#
# Epoch 00126: loss improved from 0.58646 to 0.58525, saving model to model_part3.hdf5
# Epoch 00127: loss improved from 0.58525 to 0.57929, saving model to model_part3.hdf5
#
# Epoch 00128: loss improved from 0.57929 to 0.57467, saving model to model_part3.hdf5
#
# Epoch 00129: loss improved from 0.57467 to 0.57074, saving model to model_part3.hdf5
#
# Epoch 00130: loss improved from 0.57074 to 0.56923, saving model to model_part3.hdf5
#
# Epoch 00131: loss improved from 0.56923 to 0.56554, saving model to model_part3.hdf5
#
# Epoch 00132: loss improved from 0.56554 to 0.55937, saving model to model_part3.hdf5
#
# Epoch 00133: loss improved from 0.55937 to 0.55620, saving model to model_part3.hdf5
#
# Epoch 00134: loss improved from 0.55620 to 0.55301, saving model to model_part3.hdf5
#
# Epoch 00135: loss improved from 0.55301 to 0.54735, saving model to model_part3.hdf5
#
# Epoch 00136: loss improved from 0.54735 to 0.54495, saving model to model_part3.hdf5
#
# Epoch 00137: loss improved from 0.54495 to 0.53926, saving model to model_part3.hdf5
#
# Epoch 00138: loss improved from 0.53926 to 0.53564, saving model to model_part3.hdf5
#
# Epoch 00139: loss improved from 0.53564 to 0.53250, saving model to model_part3.hdf5
#
# Epoch 00140: loss improved from 0.53250 to 0.52739, saving model to model_part3.hdf5
#
# Epoch 00141: loss improved from 0.52739 to 0.52315, saving model to model_part3.hdf5
#
# Epoch 00142: loss improved from 0.52315 to 0.52003, saving model to model_part3.hdf5
#
# Epoch 00143: loss improved from 0.52003 to 0.51691, saving model to model_part3.hdf5
#
# Epoch 00144: loss improved from 0.51691 to 0.51151, saving model to model_part3.hdf5
#
# Epoch 00145: loss improved from 0.51151 to 0.51122, saving model to model_part3.hdf5
#
# Epoch 00146: loss improved from 0.51122 to 0.50552, saving model to model_part3.hdf5
#
# Epoch 00147: loss improved from 0.50552 to 0.50379, saving model to model_part3.hdf5
#
# Epoch 00148: loss improved from 0.50379 to 0.49647, saving model to model_part3.hdf5
#
# Epoch 00149: loss improved from 0.49647 to 0.49299, saving model to model_part3.hdf5
#
# Epoch 00150: loss improved from 0.49299 to 0.49116, saving model to model_part3.hdf5
#
# Epoch 00151: loss improved from 0.49116 to 0.48543, saving model to model_part3.hdf5
#
# Epoch 00152: loss improved from 0.48543 to 0.48237, saving model to model_part3.hdf5
#
# Epoch 00153: loss improved from 0.48237 to 0.47698, saving model to model_part3.hdf5
#
# Epoch 00154: loss improved from 0.47698 to 0.47343, saving model to model_part3.hdf5
#
# Epoch 00155: loss improved from 0.47343 to 0.47131, saving model to model_part3.hdf5
#
# Epoch 00156: loss improved from 0.47131 to 0.46656, saving model to model_part3.hdf5
#
# Epoch 00157: loss improved from 0.46656 to 0.46106, saving model to model_part3.hdf5
#
# Epoch 00158: loss did not improve from 0.46106
#
# Epoch 00159: loss improved from 0.46106 to 0.45373, saving model to model_part3.hdf5
#
# Epoch 00160: loss improved from 0.45373 to 0.45032, saving model to model_part3.hdf5
#
# Epoch 00161: loss improved from 0.45032 to 0.44752, saving model to model_part3.hdf5
#
# Epoch 00162: loss improved from 0.44752 to 0.44215, saving model to model_part3.hdf5
#
# Epoch 00163: loss improved from 0.44215 to 0.43782, saving model to model_part3.hdf5
#
# Epoch 00164: loss improved from 0.43782 to 0.43470, saving model to model_part3.hdf5
#
# Epoch 00165: loss improved from 0.43470 to 0.43378, saving model to model_part3.hdf5
#
# Epoch 00166: loss improved from 0.43378 to 0.42843, saving model to model_part3.hdf5
#
# Epoch 00167: loss improved from 0.42843 to 0.42793, saving model to model_part3.hdf5
#
# Epoch 00168: loss improved from 0.42793 to 0.42001, saving model to model_part3.hdf5
#
# Epoch 00169: loss improved from 0.42001 to 0.41491, saving model to model_part3.hdf5
#
# Epoch 00170: loss improved from 0.41491 to 0.41121, saving model to model_part3.hdf5
#
# Epoch 00171: loss improved from 0.41121 to 0.40762, saving model to model_part3.hdf5
#
# Epoch 00172: loss improved from 0.40762 to 0.40474, saving model to model_part3.hdf5
#
# Epoch 00173: loss did not improve from 0.40474
#
# Epoch 00174: loss improved from 0.40474 to 0.39767, saving model to model_part3.hdf5
#
# Epoch 00175: loss improved from 0.39767 to 0.39589, saving model to model_part3.hdf5
#
# Epoch 00176: loss improved from 0.39589 to 0.38983, saving model to model_part3.hdf5
#
# Epoch 00177: loss improved from 0.38983 to 0.38641, saving model to model_part3.hdf5
#
# Epoch 00178: loss improved from 0.38641 to 0.38206, saving model to model_part3.hdf5
#
# Epoch 00179: loss improved from 0.38206 to 0.38098, saving model to model_part3.hdf5
#
# Epoch 00180: loss improved from 0.38098 to 0.37627, saving model to model_part3.hdf5
#
# Epoch 00181: loss improved from 0.37627 to 0.37182, saving model to model_part3.hdf5
#
# Epoch 00182: loss improved from 0.37182 to 0.36723, saving model to model_part3.hdf5
#
# Epoch 00183: loss improved from 0.36723 to 0.36545, saving model to model_part3.hdf5
#
# Epoch 00184: loss improved from 0.36545 to 0.36085, saving model to model_part3.hdf5
#
# Epoch 00185: loss improved from 0.36085 to 0.36032, saving model to model_part3.hdf5
#
# Epoch 00186: loss improved from 0.36032 to 0.35639, saving model to model_part3.hdf5
#
# Epoch 00187: loss improved from 0.35639 to 0.35176, saving model to model_part3.hdf5
#
# Epoch 00188: loss improved from 0.35176 to 0.34634, saving model to model_part3.hdf5
#
# Epoch 00189: loss improved from 0.34634 to 0.34457, saving model to model_part3.hdf5
#
# Epoch 00190: loss did not improve from 0.34457
#
# Epoch 00191: loss improved from 0.34457 to 0.34219, saving model to model_part3.hdf5
#
# Epoch 00192: loss improved from 0.34219 to 0.33496, saving model to model_part3.hdf5
#
# Epoch 00193: loss improved from 0.33496 to 0.33143, saving model to model_part3.hdf5
#
# Epoch 00194: loss improved from 0.33143 to 0.32976, saving model to model_part3.hdf5
#
# Epoch 00195: loss improved from 0.32976 to 0.32475, saving model to model_part3.hdf5
#
# Epoch 00196: loss improved from 0.32475 to 0.32322, saving model to model_part3.hdf5
#
# Epoch 00197: loss did not improve from 0.32322
#
# Epoch 00198: loss improved from 0.32322 to 0.31699, saving model to model_part3.hdf5
#
# Epoch 00199: loss did not improve from 0.31699
#
# Epoch 00200: loss improved from 0.31699 to 0.31171, saving model to model_part3.hdf5
#
# Epoch 00201: loss improved from 0.31171 to 0.30775, saving model to model_part3.hdf5
#
# Epoch 00202: loss improved from 0.30775 to 0.30772, saving model to model_part3.hdf5
#
# Epoch 00203: loss improved from 0.30772 to 0.30431, saving model to model_part3.hdf5
#
# Epoch 00204: loss improved from 0.30431 to 0.30009, saving model to model_part3.hdf5
#
# Epoch 00205: loss improved from 0.30009 to 0.29779, saving model to model_part3.hdf5
#
# Epoch 00206: loss did not improve from 0.29779
#
# Epoch 00207: loss did not improve from 0.29779
#
# Epoch 00208: loss improved from 0.29779 to 0.29029, saving model to model_part3.hdf5
#
# Epoch 00209: loss improved from 0.29029 to 0.28679, saving model to model_part3.hdf5
#
# Epoch 00210: loss improved from 0.28679 to 0.28428, saving model to model_part3.hdf5
#
# Epoch 00211: loss did not improve from 0.28428
#
# Epoch 00212: loss improved from 0.28428 to 0.28035, saving model to model_part3.hdf5
#
# Epoch 00213: loss improved from 0.28035 to 0.27702, saving model to model_part3.hdf5
#
# Epoch 00214: loss improved from 0.27702 to 0.27692, saving model to model_part3.hdf5
#
# Epoch 00215: loss improved from 0.27692 to 0.27484, saving model to model_part3.hdf5
#
# Epoch 00216: loss improved from 0.27484 to 0.27020, saving model to model_part3.hdf5
#
# Epoch 00217: loss improved from 0.27020 to 0.26865, saving model to model_part3.hdf5
#
# Epoch 00218: loss improved from 0.26865 to 0.26693, saving model to model_part3.hdf5
#
# Epoch 00219: loss improved from 0.26693 to 0.26678, saving model to model_part3.hdf5
#
# Epoch 00220: loss improved from 0.26678 to 0.26227, saving model to model_part3.hdf5
#
# Epoch 00221: loss improved from 0.26227 to 0.25864, saving model to model_part3.hdf5
#
# Epoch 00222: loss improved from 0.25864 to 0.25641, saving model to model_part3.hdf5
#
# Epoch 00223: loss improved from 0.25641 to 0.25328, saving model to model_part3.hdf5
#
# Epoch 00224: loss improved from 0.25328 to 0.25021, saving model to model_part3.hdf5
#
# Epoch 00225: loss did not improve from 0.25021
#
# Epoch 00226: loss improved from 0.25021 to 0.24882, saving model to model_part3.hdf5
#
# Epoch 00227: loss improved from 0.24882 to 0.24832, saving model to model_part3.hdf5
# Epoch 00228: loss improved from 0.24832 to 0.24308, saving model to model_part3.hdf5
#
# Epoch 00229: loss did not improve from 0.24308
#
# Epoch 00230: loss improved from 0.24308 to 0.24086, saving model to model_part3.hdf5
#
# Epoch 00231: loss improved from 0.24086 to 0.23713, saving model to model_part3.hdf5
#
# Epoch 00232: loss improved from 0.23713 to 0.23412, saving model to model_part3.hdf5
#
# Epoch 00233: loss did not improve from 0.23412
#
# Epoch 00234: loss improved from 0.23412 to 0.23170, saving model to model_part3.hdf5
#
# Epoch 00235: loss improved from 0.23170 to 0.22852, saving model to model_part3.hdf5
#
# Epoch 00236: loss did not improve from 0.22852
#
# Epoch 00237: loss did not improve from 0.22852
#
# Epoch 00238: loss improved from 0.22852 to 0.22534, saving model to model_part3.hdf5
#
# Epoch 00239: loss improved from 0.22534 to 0.22241, saving model to model_part3.hdf5
#
# Epoch 00240: loss improved from 0.22241 to 0.22016, saving model to model_part3.hdf5
#
# Epoch 00241: loss did not improve from 0.22016
#
# Epoch 00242: loss improved from 0.22016 to 0.21701, saving model to model_part3.hdf5
#
# Epoch 00243: loss improved from 0.21701 to 0.21538, saving model to model_part3.hdf5
#
# Epoch 00244: loss improved from 0.21538 to 0.21480, saving model to model_part3.hdf5
#
# Epoch 00245: loss improved from 0.21480 to 0.21238, saving model to model_part3.hdf5
#
# Epoch 00246: loss improved from 0.21238 to 0.21154, saving model to model_part3.hdf5
#
# Epoch 00247: loss did not improve from 0.21154
#
# Epoch 00248: loss improved from 0.21154 to 0.20736, saving model to model_part3.hdf5
#
# Epoch 00249: loss improved from 0.20736 to 0.20460, saving model to model_part3.hdf5
#
# Epoch 00250: loss improved from 0.20460 to 0.20267, saving model to model_part3.hdf5
#
# Epoch 00251: loss improved from 0.20267 to 0.20133, saving model to model_part3.hdf5
#
# Epoch 00252: loss did not improve from 0.20133
#
# Epoch 00253: loss improved from 0.20133 to 0.20072, saving model to model_part3.hdf5
#
# Epoch 00254: loss improved from 0.20072 to 0.19777, saving model to model_part3.hdf5
#
# Epoch 00255: loss improved from 0.19777 to 0.19631, saving model to model_part3.hdf5
#
# Epoch 00256: loss did not improve from 0.19631
#
# Epoch 00257: loss did not improve from 0.19631
#
# Epoch 00258: loss improved from 0.19631 to 0.19228, saving model to model_part3.hdf5
#
# Epoch 00259: loss did not improve from 0.19228
#
# Epoch 00260: loss improved from 0.19228 to 0.18904, saving model to model_part3.hdf5
#
# Epoch 00261: loss improved from 0.18904 to 0.18858, saving model to model_part3.hdf5
#
# Epoch 00262: loss improved from 0.18858 to 0.18620, saving model to model_part3.hdf5
#
# Epoch 00263: loss improved from 0.18620 to 0.18603, saving model to model_part3.hdf5
#
# Epoch 00264: loss improved from 0.18603 to 0.18247, saving model to model_part3.hdf5
#
# Epoch 00265: loss did not improve from 0.18247
#
# Epoch 00266: loss improved from 0.18247 to 0.18166, saving model to model_part3.hdf5
#
# Epoch 00267: loss improved from 0.18166 to 0.17972, saving model to model_part3.hdf5
#
# Epoch 00268: loss did not improve from 0.17972
#
# Epoch 00269: loss did not improve from 0.17972
#
# Epoch 00270: loss improved from 0.17972 to 0.17787, saving model to model_part3.hdf5
#
# Epoch 00271: loss improved from 0.17787 to 0.17649, saving model to model_part3.hdf5
#
# Epoch 00272: loss did not improve from 0.17649
#
# Epoch 00273: loss improved from 0.17649 to 0.17359, saving model to model_part3.hdf5
#
# Epoch 00274: loss improved from 0.17359 to 0.17052, saving model to model_part3.hdf5
#
# Epoch 00275: loss improved from 0.17052 to 0.16986, saving model to model_part3.hdf5
#
# Epoch 00276: loss improved from 0.16986 to 0.16909, saving model to model_part3.hdf5
#
# Epoch 00277: loss did not improve from 0.16909
#
# Epoch 00278: loss improved from 0.16909 to 0.16750, saving model to model_part3.hdf5
#
# Epoch 00279: loss improved from 0.16750 to 0.16633, saving model to model_part3.hdf5
#
# Epoch 00280: loss improved from 0.16633 to 0.16447, saving model to model_part3.hdf5
#
# Epoch 00281: loss did not improve from 0.16447
#
# Epoch 00282: loss improved from 0.16447 to 0.16204, saving model to model_part3.hdf5
#
# Epoch 00283: loss improved from 0.16204 to 0.16092, saving model to model_part3.hdf5
#
# Epoch 00284: loss improved from 0.16092 to 0.15925, saving model to model_part3.hdf5
#
# Epoch 00285: loss did not improve from 0.15925
#
# Epoch 00286: loss improved from 0.15925 to 0.15755, saving model to model_part3.hdf5
#
# Epoch 00287: loss did not improve from 0.15755
#
# Epoch 00288: loss did not improve from 0.15755
#
# Epoch 00289: loss improved from 0.15755 to 0.15481, saving model to model_part3.hdf5
#
# Epoch 00290: loss did not improve from 0.15481
#
# Epoch 00291: loss improved from 0.15481 to 0.15302, saving model to model_part3.hdf5
#
# Epoch 00292: loss did not improve from 0.15302
#
# Epoch 00293: loss improved from 0.15302 to 0.15032, saving model to model_part3.hdf5
#
# Epoch 00294: loss improved from 0.15032 to 0.14863, saving model to model_part3.hdf5
#
# Epoch 00295: loss did not improve from 0.14863
#
# Epoch 00296: loss did not improve from 0.14863
# Testing the model

# %%
plt.plot(percent_features, acc)
plt.xlabel("Percent Features")
plt.ylabel("Accuracy")
plt.title("Percent Features vs Accuracy")
plt.show()
