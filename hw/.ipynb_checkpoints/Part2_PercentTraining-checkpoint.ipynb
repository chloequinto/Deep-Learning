# %% [markdown]
# # Part 2: Percentage of Training Dataset
#
# ### Goal:
# Use 20%, 30%, 40%, 50%, 60%, 70%, 80%, 90%, and 100% of the total training dataset to train the neural work and test on it, respectively. You build 9 systems. Plot a graph where the axis indicate the percentage of the training set you used to train a system, and y-axis indicate the accuracy on the test set of each system

# %%
import warnings 
warnings.filterwarnings('ignore') # feel free to comment this out 

import h5py
import numpy as np
import matplotlib.pyplot as plt 

import sklearn 
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.utils import to_categorical
from keras import layers
from keras import models 
from keras.layers import Dense
from keras import optimizers 
from keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
import math

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
def dataProcessing(): 
    wine = sklearn.datasets.load_wine()
    
    df = pd.DataFrame(wine.data)
    df.columns = wine.feature_names
    df["class"] = wine.target
    
    labels = df.loc[:,["class"]] 
    features = df.drop(["class"],axis=1)
    
    xtrain, xtest, ytrain, ytest = train_test_split(features, labels)
    ytrain = to_categorical(ytrain, 3)
    ytest = to_categorical(ytest,3)
    
    scale = MinMaxScaler(feature_range=(0,1))
    xtrain = scale.fit_transform(xtrain)
    xtest = scale.fit_transform(xtest)
    
    return xtrain, xtest, ytrain, ytest

# %% [markdown]
# Discussion:
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; I used the training set percentage to find the compliment(validation split). In other words, if I want 20% of the training set to be used during training, I'll just utilize validation_split attribute in model.fit() with the compliment, 80%.

# %%
def trainModel(val_split, xtrain, ytrain):
    '''
    Builds and runs training model 
    '''
    print("Training the Model")
    
    model = Sequential()
    model.add(Dense(10, input_dim=xtrain.shape[1],activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(4, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    
    model.compile(loss="categorical_crossentropy", optimizer = optimizers.RMSprop(lr = 1e-3), metrics = ["acc"])
    
    # Save weights 
    checkpoint = ModelCheckpoint("model_part2.hdf5", monitor="loss", verbose=1, save_best_only = True, mode="auto", period=1)
    
    # Apply early stopping to prevent overfitting 
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=0, mode='auto',restore_best_weights=True)
    
    # Run Model 
    history = model.fit(xtrain, ytrain, batch_size=50, epochs=2000, verbose =0, validation_split=val_split, callbacks=[checkpoint,monitor])

# %%
def testModel(xtest, ytest): 
    '''
    Builds and runs testing model 
    '''
    print("Testing the model")
    
    evalModel = Sequential()
    evalModel.add(Dense(10, input_dim=xtest.shape[1],activation='relu'))
    evalModel.add(Dense(8, activation='relu'))
    evalModel.add(Dense(6, activation='relu'))
    evalModel.add(Dense(6, activation='relu'))
    evalModel.add(Dense(4, activation='relu'))
    evalModel.add(Dense(3, activation='softmax'))


    evalModel.load_weights('model_part2.hdf5')
    evalModel.compile(loss="categorical_crossentropy", optimizer = optimizers.RMSprop(lr = 1e-3), metrics = ["acc"])
    
    lossAndAcc = evalModel.evaluate(xtest, ytest)

    return lossAndAcc[1]

# %%
def main(train_sizes, accuracy): 
    '''
    Main driver for program 
    '''

    xtrain, xtest, ytrain, ytest = dataProcessing()

    for i in range(len(train_sizes)): 
        print("====================================================")
        print("Percent Training Size ", train_sizes[i])
        
        validation_split = round(1-train_sizes[i],2)
        
        # Train Model
        trainModel(validation_split, xtrain, ytrain)
        
        # Test Model 
        currAcc = testModel(xtest, ytest)
        
        # Add accuracy to our list 
        accuracy.append(currAcc)
        
        print("====================================================\n")
    return accuracy

# %%
accuracy = []
train_sizes = [0.20, 0.30, 0.40, 0.5, 0.6, 0.7, 0.8, 0.9, 1]

accuracy = main(train_sizes, accuracy)
# Out:
# ====================================================
# Percent Training Size  0.2
# Training the Model
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Epoch 00001: loss improved from inf to 1.07455, saving model to model_part2.hdf5
#
# Epoch 00002: loss improved from 1.07455 to 1.05943, saving model to model_part2.hdf5
#
# Epoch 00003: loss improved from 1.05943 to 1.04871, saving model to model_part2.hdf5
#
# Epoch 00004: loss improved from 1.04871 to 1.04065, saving model to model_part2.hdf5
#
# Epoch 00005: loss improved from 1.04065 to 1.03384, saving model to model_part2.hdf5
#
# Epoch 00006: loss improved from 1.03384 to 1.02809, saving model to model_part2.hdf5
#
# Epoch 00007: loss improved from 1.02809 to 1.02275, saving model to model_part2.hdf5
#
# Epoch 00008: loss improved from 1.02275 to 1.01806, saving model to model_part2.hdf5
#
# Epoch 00009: loss improved from 1.01806 to 1.01404, saving model to model_part2.hdf5
#
# Epoch 00010: loss improved from 1.01404 to 1.01037, saving model to model_part2.hdf5
#
# Epoch 00011: loss improved from 1.01037 to 1.00686, saving model to model_part2.hdf5
#
# Epoch 00012: loss improved from 1.00686 to 1.00342, saving model to model_part2.hdf5
#
# Epoch 00013: loss improved from 1.00342 to 1.00010, saving model to model_part2.hdf5
#
# Epoch 00014: loss improved from 1.00010 to 0.99675, saving model to model_part2.hdf5
#
# Epoch 00015: loss improved from 0.99675 to 0.99341, saving model to model_part2.hdf5
#
# Epoch 00016: loss improved from 0.99341 to 0.99012, saving model to model_part2.hdf5
#
# Epoch 00017: loss improved from 0.99012 to 0.98685, saving model to model_part2.hdf5
#
# Epoch 00018: loss improved from 0.98685 to 0.98361, saving model to model_part2.hdf5
#
# Epoch 00019: loss improved from 0.98361 to 0.98040, saving model to model_part2.hdf5
#
# Epoch 00020: loss improved from 0.98040 to 0.97729, saving model to model_part2.hdf5
#
# Epoch 00021: loss improved from 0.97729 to 0.97419, saving model to model_part2.hdf5
#
# Epoch 00022: loss improved from 0.97419 to 0.97112, saving model to model_part2.hdf5
#
# Epoch 00023: loss improved from 0.97112 to 0.96802, saving model to model_part2.hdf5
#
# Epoch 00024: loss improved from 0.96802 to 0.96494, saving model to model_part2.hdf5
#
# Epoch 00025: loss improved from 0.96494 to 0.96189, saving model to model_part2.hdf5
#
# Epoch 00026: loss improved from 0.96189 to 0.95882, saving model to model_part2.hdf5
#
# Epoch 00027: loss improved from 0.95882 to 0.95575, saving model to model_part2.hdf5
#
# Epoch 00028: loss improved from 0.95575 to 0.95268, saving model to model_part2.hdf5
#
# Epoch 00029: loss improved from 0.95268 to 0.94952, saving model to model_part2.hdf5
#
# Epoch 00030: loss improved from 0.94952 to 0.94640, saving model to model_part2.hdf5
#
# Epoch 00031: loss improved from 0.94640 to 0.94325, saving model to model_part2.hdf5
#
# Epoch 00032: loss improved from 0.94325 to 0.94011, saving model to model_part2.hdf5
#
# Epoch 00033: loss improved from 0.94011 to 0.93699, saving model to model_part2.hdf5
#
# Epoch 00034: loss improved from 0.93699 to 0.93385, saving model to model_part2.hdf5
#
# Epoch 00035: loss improved from 0.93385 to 0.93066, saving model to model_part2.hdf5
#
# Epoch 00036: loss improved from 0.93066 to 0.92747, saving model to model_part2.hdf5
#
# Epoch 00037: loss improved from 0.92747 to 0.92419, saving model to model_part2.hdf5
#
# Epoch 00038: loss improved from 0.92419 to 0.92091, saving model to model_part2.hdf5
#
# Epoch 00039: loss improved from 0.92091 to 0.91751, saving model to model_part2.hdf5
#
# Epoch 00040: loss improved from 0.91751 to 0.91411, saving model to model_part2.hdf5
#
# Epoch 00041: loss improved from 0.91411 to 0.91063, saving model to model_part2.hdf5
#
# Epoch 00042: loss improved from 0.91063 to 0.90711, saving model to model_part2.hdf5
#
# Epoch 00043: loss improved from 0.90711 to 0.90356, saving model to model_part2.hdf5
#
# Epoch 00044: loss improved from 0.90356 to 0.89990, saving model to model_part2.hdf5
#
# Epoch 00045: loss improved from 0.89990 to 0.89618, saving model to model_part2.hdf5
#
# Epoch 00046: loss improved from 0.89618 to 0.89242, saving model to model_part2.hdf5
#
# Epoch 00047: loss improved from 0.89242 to 0.88863, saving model to model_part2.hdf5
#
# Epoch 00048: loss improved from 0.88863 to 0.88479, saving model to model_part2.hdf5
#
# Epoch 00049: loss improved from 0.88479 to 0.88093, saving model to model_part2.hdf5
#
# Epoch 00050: loss improved from 0.88093 to 0.87699, saving model to model_part2.hdf5
#
# Epoch 00051: loss improved from 0.87699 to 0.87300, saving model to model_part2.hdf5
#
# Epoch 00052: loss improved from 0.87300 to 0.86897, saving model to model_part2.hdf5
#
# Epoch 00053: loss improved from 0.86897 to 0.86488, saving model to model_part2.hdf5
#
# Epoch 00054: loss improved from 0.86488 to 0.86073, saving model to model_part2.hdf5
#
# Epoch 00055: loss improved from 0.86073 to 0.85656, saving model to model_part2.hdf5
#
# Epoch 00056: loss improved from 0.85656 to 0.85262, saving model to model_part2.hdf5
#
# Epoch 00057: loss improved from 0.85262 to 0.84857, saving model to model_part2.hdf5
#
# Epoch 00058: loss improved from 0.84857 to 0.84459, saving model to model_part2.hdf5
#
# Epoch 00059: loss improved from 0.84459 to 0.84046, saving model to model_part2.hdf5
#
# Epoch 00060: loss improved from 0.84046 to 0.83641, saving model to model_part2.hdf5
#
# Epoch 00061: loss improved from 0.83641 to 0.83234, saving model to model_part2.hdf5
#
# Epoch 00062: loss improved from 0.83234 to 0.82826, saving model to model_part2.hdf5
#
# Epoch 00063: loss improved from 0.82826 to 0.82416, saving model to model_part2.hdf5
#
# Epoch 00064: loss improved from 0.82416 to 0.81992, saving model to model_part2.hdf5
#
# Epoch 00065: loss improved from 0.81992 to 0.81545, saving model to model_part2.hdf5
#
# Epoch 00066: loss improved from 0.81545 to 0.81098, saving model to model_part2.hdf5
#
# Epoch 00067: loss improved from 0.81098 to 0.80663, saving model to model_part2.hdf5
#
# Epoch 00068: loss improved from 0.80663 to 0.80235, saving model to model_part2.hdf5
#
# Epoch 00069: loss improved from 0.80235 to 0.79809, saving model to model_part2.hdf5
#
# Epoch 00070: loss improved from 0.79809 to 0.79384, saving model to model_part2.hdf5
#
# Epoch 00071: loss improved from 0.79384 to 0.78952, saving model to model_part2.hdf5
#
# Epoch 00072: loss improved from 0.78952 to 0.78522, saving model to model_part2.hdf5
#
# Epoch 00073: loss improved from 0.78522 to 0.78088, saving model to model_part2.hdf5
#
# Epoch 00074: loss improved from 0.78088 to 0.77658, saving model to model_part2.hdf5
#
# Epoch 00075: loss improved from 0.77658 to 0.77222, saving model to model_part2.hdf5
#
# Epoch 00076: loss improved from 0.77222 to 0.76784, saving model to model_part2.hdf5
#
# Epoch 00077: loss improved from 0.76784 to 0.76343, saving model to model_part2.hdf5
#
# Epoch 00078: loss improved from 0.76343 to 0.75901, saving model to model_part2.hdf5
#
# Epoch 00079: loss improved from 0.75901 to 0.75456, saving model to model_part2.hdf5
#
# Epoch 00080: loss improved from 0.75456 to 0.75007, saving model to model_part2.hdf5
#
# Epoch 00081: loss improved from 0.75007 to 0.74554, saving model to model_part2.hdf5
#
# Epoch 00082: loss improved from 0.74554 to 0.74101, saving model to model_part2.hdf5
#
# Epoch 00083: loss improved from 0.74101 to 0.73649, saving model to model_part2.hdf5
#
# Epoch 00084: loss improved from 0.73649 to 0.73225, saving model to model_part2.hdf5
#
# Epoch 00085: loss improved from 0.73225 to 0.72783, saving model to model_part2.hdf5
#
# Epoch 00086: loss improved from 0.72783 to 0.72354, saving model to model_part2.hdf5
#
# Epoch 00087: loss improved from 0.72354 to 0.71908, saving model to model_part2.hdf5
#
# Epoch 00088: loss improved from 0.71908 to 0.71471, saving model to model_part2.hdf5
#
# Epoch 00089: loss improved from 0.71471 to 0.71029, saving model to model_part2.hdf5
#
# Epoch 00090: loss improved from 0.71029 to 0.70590, saving model to model_part2.hdf5
#
# Epoch 00091: loss improved from 0.70590 to 0.70157, saving model to model_part2.hdf5
#
# Epoch 00092: loss improved from 0.70157 to 0.69718, saving model to model_part2.hdf5
# Epoch 00093: loss improved from 0.69718 to 0.69280, saving model to model_part2.hdf5
#
# Epoch 00094: loss improved from 0.69280 to 0.68844, saving model to model_part2.hdf5
#
# Epoch 00095: loss improved from 0.68844 to 0.68412, saving model to model_part2.hdf5
#
# Epoch 00096: loss improved from 0.68412 to 0.67980, saving model to model_part2.hdf5
#
# Epoch 00097: loss improved from 0.67980 to 0.67555, saving model to model_part2.hdf5
#
# Epoch 00098: loss improved from 0.67555 to 0.67125, saving model to model_part2.hdf5
#
# Epoch 00099: loss improved from 0.67125 to 0.66698, saving model to model_part2.hdf5
#
# Epoch 00100: loss improved from 0.66698 to 0.66273, saving model to model_part2.hdf5
#
# Epoch 00101: loss improved from 0.66273 to 0.65849, saving model to model_part2.hdf5
#
# Epoch 00102: loss improved from 0.65849 to 0.65425, saving model to model_part2.hdf5
#
# Epoch 00103: loss improved from 0.65425 to 0.65002, saving model to model_part2.hdf5
#
# Epoch 00104: loss improved from 0.65002 to 0.64580, saving model to model_part2.hdf5
#
# Epoch 00105: loss improved from 0.64580 to 0.64157, saving model to model_part2.hdf5
#
# Epoch 00106: loss improved from 0.64157 to 0.63736, saving model to model_part2.hdf5
#
# Epoch 00107: loss improved from 0.63736 to 0.63313, saving model to model_part2.hdf5
#
# Epoch 00108: loss improved from 0.63313 to 0.62919, saving model to model_part2.hdf5
#
# Epoch 00109: loss improved from 0.62919 to 0.62542, saving model to model_part2.hdf5
#
# Epoch 00110: loss improved from 0.62542 to 0.62130, saving model to model_part2.hdf5
#
# Epoch 00111: loss improved from 0.62130 to 0.61745, saving model to model_part2.hdf5
#
# Epoch 00112: loss improved from 0.61745 to 0.61361, saving model to model_part2.hdf5
#
# Epoch 00113: loss improved from 0.61361 to 0.60978, saving model to model_part2.hdf5
#
# Epoch 00114: loss improved from 0.60978 to 0.60580, saving model to model_part2.hdf5
#
# Epoch 00115: loss improved from 0.60580 to 0.60197, saving model to model_part2.hdf5
#
# Epoch 00116: loss improved from 0.60197 to 0.59820, saving model to model_part2.hdf5
#
# Epoch 00117: loss improved from 0.59820 to 0.59440, saving model to model_part2.hdf5
#
# Epoch 00118: loss improved from 0.59440 to 0.59082, saving model to model_part2.hdf5
#
# Epoch 00119: loss improved from 0.59082 to 0.58699, saving model to model_part2.hdf5
#
# Epoch 00120: loss improved from 0.58699 to 0.58326, saving model to model_part2.hdf5
#
# Epoch 00121: loss improved from 0.58326 to 0.57964, saving model to model_part2.hdf5
#
# Epoch 00122: loss improved from 0.57964 to 0.57596, saving model to model_part2.hdf5
#
# Epoch 00123: loss improved from 0.57596 to 0.57227, saving model to model_part2.hdf5
#
# Epoch 00124: loss improved from 0.57227 to 0.56873, saving model to model_part2.hdf5
#
# Epoch 00125: loss improved from 0.56873 to 0.56520, saving model to model_part2.hdf5
#
# Epoch 00126: loss improved from 0.56520 to 0.56153, saving model to model_part2.hdf5
#
# Epoch 00127: loss improved from 0.56153 to 0.55805, saving model to model_part2.hdf5
#
# Epoch 00128: loss improved from 0.55805 to 0.55441, saving model to model_part2.hdf5
#
# Epoch 00129: loss improved from 0.55441 to 0.55081, saving model to model_part2.hdf5
#
# Epoch 00130: loss improved from 0.55081 to 0.54733, saving model to model_part2.hdf5
#
# Epoch 00131: loss improved from 0.54733 to 0.54390, saving model to model_part2.hdf5
#
# Epoch 00132: loss improved from 0.54390 to 0.54029, saving model to model_part2.hdf5
#
# Epoch 00133: loss improved from 0.54029 to 0.53676, saving model to model_part2.hdf5
#
# Epoch 00134: loss improved from 0.53676 to 0.53327, saving model to model_part2.hdf5
#
# Epoch 00135: loss improved from 0.53327 to 0.52991, saving model to model_part2.hdf5
#
# Epoch 00136: loss improved from 0.52991 to 0.52655, saving model to model_part2.hdf5
#
# Epoch 00137: loss improved from 0.52655 to 0.52334, saving model to model_part2.hdf5
#
# Epoch 00138: loss improved from 0.52334 to 0.52000, saving model to model_part2.hdf5
#
# Epoch 00139: loss improved from 0.52000 to 0.51650, saving model to model_part2.hdf5
#
# Epoch 00140: loss improved from 0.51650 to 0.51338, saving model to model_part2.hdf5
#
# Epoch 00141: loss improved from 0.51338 to 0.51013, saving model to model_part2.hdf5
#
# Epoch 00142: loss improved from 0.51013 to 0.50679, saving model to model_part2.hdf5
#
# Epoch 00143: loss improved from 0.50679 to 0.50373, saving model to model_part2.hdf5
#
# Epoch 00144: loss improved from 0.50373 to 0.50040, saving model to model_part2.hdf5
#
# Epoch 00145: loss improved from 0.50040 to 0.49705, saving model to model_part2.hdf5
#
# Epoch 00146: loss improved from 0.49705 to 0.49405, saving model to model_part2.hdf5
#
# Epoch 00147: loss improved from 0.49405 to 0.49090, saving model to model_part2.hdf5
#
# Epoch 00148: loss improved from 0.49090 to 0.48774, saving model to model_part2.hdf5
#
# Epoch 00149: loss improved from 0.48774 to 0.48468, saving model to model_part2.hdf5
#
# Epoch 00150: loss improved from 0.48468 to 0.48146, saving model to model_part2.hdf5
#
# Epoch 00151: loss improved from 0.48146 to 0.47856, saving model to model_part2.hdf5
#
# Epoch 00152: loss improved from 0.47856 to 0.47612, saving model to model_part2.hdf5
#
# Epoch 00153: loss improved from 0.47612 to 0.47313, saving model to model_part2.hdf5
#
# Epoch 00154: loss improved from 0.47313 to 0.47005, saving model to model_part2.hdf5
#
# Epoch 00155: loss improved from 0.47005 to 0.46716, saving model to model_part2.hdf5
#
# Epoch 00156: loss improved from 0.46716 to 0.46432, saving model to model_part2.hdf5
#
# Epoch 00157: loss improved from 0.46432 to 0.46251, saving model to model_part2.hdf5
#
# Epoch 00158: loss improved from 0.46251 to 0.46026, saving model to model_part2.hdf5
#
# Epoch 00159: loss improved from 0.46026 to 0.45749, saving model to model_part2.hdf5
#
# Epoch 00160: loss improved from 0.45749 to 0.45456, saving model to model_part2.hdf5
#
# Epoch 00161: loss improved from 0.45456 to 0.45290, saving model to model_part2.hdf5
#
# Epoch 00162: loss improved from 0.45290 to 0.44978, saving model to model_part2.hdf5
#
# Epoch 00163: loss improved from 0.44978 to 0.44766, saving model to model_part2.hdf5
#
# Epoch 00164: loss improved from 0.44766 to 0.44517, saving model to model_part2.hdf5
#
# Epoch 00165: loss improved from 0.44517 to 0.44293, saving model to model_part2.hdf5
#
# Epoch 00166: loss improved from 0.44293 to 0.44068, saving model to model_part2.hdf5
#
# Epoch 00167: loss improved from 0.44068 to 0.43840, saving model to model_part2.hdf5
#
# Epoch 00168: loss improved from 0.43840 to 0.43614, saving model to model_part2.hdf5
#
# Epoch 00169: loss improved from 0.43614 to 0.43387, saving model to model_part2.hdf5
#
# Epoch 00170: loss improved from 0.43387 to 0.43160, saving model to model_part2.hdf5
#
# Epoch 00171: loss improved from 0.43160 to 0.42939, saving model to model_part2.hdf5
#
# Epoch 00172: loss improved from 0.42939 to 0.42719, saving model to model_part2.hdf5
#
# Epoch 00173: loss improved from 0.42719 to 0.42515, saving model to model_part2.hdf5
#
# Epoch 00174: loss improved from 0.42515 to 0.42389, saving model to model_part2.hdf5
#
# Epoch 00175: loss improved from 0.42389 to 0.42030, saving model to model_part2.hdf5
#
# Epoch 00176: loss improved from 0.42030 to 0.41813, saving model to model_part2.hdf5
#
# Epoch 00177: loss improved from 0.41813 to 0.41614, saving model to model_part2.hdf5
#
# Epoch 00178: loss improved from 0.41614 to 0.41421, saving model to model_part2.hdf5
#
# Epoch 00179: loss improved from 0.41421 to 0.41188, saving model to model_part2.hdf5
#
# Epoch 00180: loss improved from 0.41188 to 0.41010, saving model to model_part2.hdf5
#
# Epoch 00181: loss improved from 0.41010 to 0.40754, saving model to model_part2.hdf5
#
# Epoch 00182: loss improved from 0.40754 to 0.40521, saving model to model_part2.hdf5
#
# Epoch 00183: loss improved from 0.40521 to 0.40343, saving model to model_part2.hdf5
#
# Epoch 00184: loss improved from 0.40343 to 0.40106, saving model to model_part2.hdf5
#
# Epoch 00185: loss improved from 0.40106 to 0.39908, saving model to model_part2.hdf5
#
# Epoch 00186: loss improved from 0.39908 to 0.39632, saving model to model_part2.hdf5
#
# Epoch 00187: loss improved from 0.39632 to 0.39413, saving model to model_part2.hdf5
#
# Epoch 00188: loss improved from 0.39413 to 0.39194, saving model to model_part2.hdf5
#
# Epoch 00189: loss improved from 0.39194 to 0.38971, saving model to model_part2.hdf5
# Testing the model
# 45/45 [==============================] - 0s 658us/step
# ====================================================
# Percent Training Size  0.3
# Training the Model
#
# Epoch 00001: loss improved from inf to 1.09857, saving model to model_part2.hdf5
#
# Epoch 00002: loss improved from 1.09857 to 1.09550, saving model to model_part2.hdf5
#
# Epoch 00003: loss improved from 1.09550 to 1.09389, saving model to model_part2.hdf5
#
# Epoch 00004: loss improved from 1.09389 to 1.09244, saving model to model_part2.hdf5
#
# Epoch 00005: loss improved from 1.09244 to 1.09099, saving model to model_part2.hdf5
#
# Epoch 00006: loss improved from 1.09099 to 1.08953, saving model to model_part2.hdf5
#
# Epoch 00007: loss improved from 1.08953 to 1.08815, saving model to model_part2.hdf5
#
# Epoch 00008: loss improved from 1.08815 to 1.08683, saving model to model_part2.hdf5
#
# Epoch 00009: loss improved from 1.08683 to 1.08555, saving model to model_part2.hdf5
#
# Epoch 00010: loss improved from 1.08555 to 1.08419, saving model to model_part2.hdf5
#
# Epoch 00011: loss improved from 1.08419 to 1.08278, saving model to model_part2.hdf5
#
# Epoch 00012: loss improved from 1.08278 to 1.08134, saving model to model_part2.hdf5
#
# Epoch 00013: loss improved from 1.08134 to 1.07983, saving model to model_part2.hdf5
#
# Epoch 00014: loss improved from 1.07983 to 1.07792, saving model to model_part2.hdf5
#
# Epoch 00015: loss improved from 1.07792 to 1.07569, saving model to model_part2.hdf5
#
# Epoch 00016: loss improved from 1.07569 to 1.07352, saving model to model_part2.hdf5
#
# Epoch 00017: loss improved from 1.07352 to 1.07154, saving model to model_part2.hdf5
#
# Epoch 00018: loss improved from 1.07154 to 1.06959, saving model to model_part2.hdf5
#
# Epoch 00019: loss improved from 1.06959 to 1.06748, saving model to model_part2.hdf5
#
# Epoch 00020: loss improved from 1.06748 to 1.06506, saving model to model_part2.hdf5
#
# Epoch 00021: loss improved from 1.06506 to 1.06271, saving model to model_part2.hdf5
#
# Epoch 00022: loss improved from 1.06271 to 1.06024, saving model to model_part2.hdf5
#
# Epoch 00023: loss improved from 1.06024 to 1.05782, saving model to model_part2.hdf5
#
# Epoch 00024: loss improved from 1.05782 to 1.05545, saving model to model_part2.hdf5
#
# Epoch 00025: loss improved from 1.05545 to 1.05299, saving model to model_part2.hdf5
#
# Epoch 00026: loss improved from 1.05299 to 1.05042, saving model to model_part2.hdf5
#
# Epoch 00027: loss improved from 1.05042 to 1.04701, saving model to model_part2.hdf5
#
# Epoch 00028: loss improved from 1.04701 to 1.04161, saving model to model_part2.hdf5
#
# Epoch 00029: loss improved from 1.04161 to 1.03464, saving model to model_part2.hdf5
#
# Epoch 00030: loss improved from 1.03464 to 1.02624, saving model to model_part2.hdf5
#
# Epoch 00031: loss improved from 1.02624 to 1.01880, saving model to model_part2.hdf5
#
# Epoch 00032: loss improved from 1.01880 to 1.01242, saving model to model_part2.hdf5
#
# Epoch 00033: loss improved from 1.01242 to 1.00685, saving model to model_part2.hdf5
#
# Epoch 00034: loss improved from 1.00685 to 1.00256, saving model to model_part2.hdf5
#
# Epoch 00035: loss improved from 1.00256 to 0.99767, saving model to model_part2.hdf5
#
# Epoch 00036: loss improved from 0.99767 to 0.99169, saving model to model_part2.hdf5
#
# Epoch 00037: loss improved from 0.99169 to 0.98680, saving model to model_part2.hdf5
#
# Epoch 00038: loss improved from 0.98680 to 0.98174, saving model to model_part2.hdf5
#
# Epoch 00039: loss improved from 0.98174 to 0.97646, saving model to model_part2.hdf5
#
# Epoch 00040: loss improved from 0.97646 to 0.97090, saving model to model_part2.hdf5
#
# Epoch 00041: loss improved from 0.97090 to 0.96575, saving model to model_part2.hdf5
#
# Epoch 00042: loss improved from 0.96575 to 0.96113, saving model to model_part2.hdf5
#
# Epoch 00043: loss improved from 0.96113 to 0.95679, saving model to model_part2.hdf5
#
# Epoch 00044: loss improved from 0.95679 to 0.94992, saving model to model_part2.hdf5
#
# Epoch 00045: loss improved from 0.94992 to 0.94461, saving model to model_part2.hdf5
#
# Epoch 00046: loss improved from 0.94461 to 0.93934, saving model to model_part2.hdf5
#
# Epoch 00047: loss improved from 0.93934 to 0.93454, saving model to model_part2.hdf5
#
# Epoch 00048: loss improved from 0.93454 to 0.92984, saving model to model_part2.hdf5
#
# Epoch 00049: loss improved from 0.92984 to 0.92465, saving model to model_part2.hdf5
#
# Epoch 00050: loss improved from 0.92465 to 0.91935, saving model to model_part2.hdf5
#
# Epoch 00051: loss improved from 0.91935 to 0.91484, saving model to model_part2.hdf5
#
# Epoch 00052: loss improved from 0.91484 to 0.90944, saving model to model_part2.hdf5
#
# Epoch 00053: loss improved from 0.90944 to 0.90466, saving model to model_part2.hdf5
#
# Epoch 00054: loss improved from 0.90466 to 0.89967, saving model to model_part2.hdf5
#
# Epoch 00055: loss improved from 0.89967 to 0.89476, saving model to model_part2.hdf5
#
# Epoch 00056: loss improved from 0.89476 to 0.88979, saving model to model_part2.hdf5
#
# Epoch 00057: loss improved from 0.88979 to 0.88472, saving model to model_part2.hdf5
#
# Epoch 00058: loss improved from 0.88472 to 0.87971, saving model to model_part2.hdf5
#
# Epoch 00059: loss improved from 0.87971 to 0.87461, saving model to model_part2.hdf5
#
# Epoch 00060: loss improved from 0.87461 to 0.86958, saving model to model_part2.hdf5
#
# Epoch 00061: loss improved from 0.86958 to 0.86466, saving model to model_part2.hdf5
#
# Epoch 00062: loss improved from 0.86466 to 0.85986, saving model to model_part2.hdf5
#
# Epoch 00063: loss improved from 0.85986 to 0.85538, saving model to model_part2.hdf5
#
# Epoch 00064: loss improved from 0.85538 to 0.84952, saving model to model_part2.hdf5
#
# Epoch 00065: loss improved from 0.84952 to 0.84409, saving model to model_part2.hdf5
#
# Epoch 00066: loss improved from 0.84409 to 0.83873, saving model to model_part2.hdf5
#
# Epoch 00067: loss improved from 0.83873 to 0.83346, saving model to model_part2.hdf5
#
# Epoch 00068: loss improved from 0.83346 to 0.82798, saving model to model_part2.hdf5
#
# Epoch 00069: loss improved from 0.82798 to 0.82246, saving model to model_part2.hdf5
#
# Epoch 00070: loss improved from 0.82246 to 0.81673, saving model to model_part2.hdf5
#
# Epoch 00071: loss improved from 0.81673 to 0.81145, saving model to model_part2.hdf5
#
# Epoch 00072: loss improved from 0.81145 to 0.80608, saving model to model_part2.hdf5
#
# Epoch 00073: loss improved from 0.80608 to 0.80096, saving model to model_part2.hdf5
#
# Epoch 00074: loss improved from 0.80096 to 0.79489, saving model to model_part2.hdf5
#
# Epoch 00075: loss improved from 0.79489 to 0.78936, saving model to model_part2.hdf5
#
# Epoch 00076: loss improved from 0.78936 to 0.78370, saving model to model_part2.hdf5
#
# Epoch 00077: loss improved from 0.78370 to 0.77815, saving model to model_part2.hdf5
#
# Epoch 00078: loss improved from 0.77815 to 0.77268, saving model to model_part2.hdf5
#
# Epoch 00079: loss improved from 0.77268 to 0.76768, saving model to model_part2.hdf5
#
# Epoch 00080: loss improved from 0.76768 to 0.76173, saving model to model_part2.hdf5
#
# Epoch 00081: loss improved from 0.76173 to 0.75663, saving model to model_part2.hdf5
#
# Epoch 00082: loss improved from 0.75663 to 0.75094, saving model to model_part2.hdf5
#
# Epoch 00083: loss improved from 0.75094 to 0.74559, saving model to model_part2.hdf5
#
# Epoch 00084: loss improved from 0.74559 to 0.73990, saving model to model_part2.hdf5
#
# Epoch 00085: loss improved from 0.73990 to 0.73446, saving model to model_part2.hdf5
#
# Epoch 00086: loss improved from 0.73446 to 0.72879, saving model to model_part2.hdf5
#
# Epoch 00087: loss improved from 0.72879 to 0.72325, saving model to model_part2.hdf5
#
# Epoch 00088: loss improved from 0.72325 to 0.71777, saving model to model_part2.hdf5
#
# Epoch 00089: loss improved from 0.71777 to 0.71238, saving model to model_part2.hdf5
#
# Epoch 00090: loss improved from 0.71238 to 0.70711, saving model to model_part2.hdf5
#
# Epoch 00091: loss improved from 0.70711 to 0.70217, saving model to model_part2.hdf5
#
# Epoch 00092: loss improved from 0.70217 to 0.69709, saving model to model_part2.hdf5
#
# Epoch 00093: loss improved from 0.69709 to 0.69186, saving model to model_part2.hdf5
#
# Epoch 00094: loss improved from 0.69186 to 0.68648, saving model to model_part2.hdf5
#
# Epoch 00095: loss improved from 0.68648 to 0.68109, saving model to model_part2.hdf5
# Epoch 00096: loss improved from 0.68109 to 0.67598, saving model to model_part2.hdf5
#
# Epoch 00097: loss improved from 0.67598 to 0.67089, saving model to model_part2.hdf5
#
# Epoch 00098: loss improved from 0.67089 to 0.66583, saving model to model_part2.hdf5
#
# Epoch 00099: loss improved from 0.66583 to 0.66067, saving model to model_part2.hdf5
#
# Epoch 00100: loss improved from 0.66067 to 0.65593, saving model to model_part2.hdf5
#
# Epoch 00101: loss improved from 0.65593 to 0.65086, saving model to model_part2.hdf5
#
# Epoch 00102: loss improved from 0.65086 to 0.64605, saving model to model_part2.hdf5
#
# Epoch 00103: loss improved from 0.64605 to 0.64138, saving model to model_part2.hdf5
#
# Epoch 00104: loss improved from 0.64138 to 0.63643, saving model to model_part2.hdf5
#
# Epoch 00105: loss improved from 0.63643 to 0.63182, saving model to model_part2.hdf5
#
# Epoch 00106: loss improved from 0.63182 to 0.62697, saving model to model_part2.hdf5
#
# Epoch 00107: loss improved from 0.62697 to 0.62263, saving model to model_part2.hdf5
#
# Epoch 00108: loss improved from 0.62263 to 0.61775, saving model to model_part2.hdf5
#
# Epoch 00109: loss improved from 0.61775 to 0.61305, saving model to model_part2.hdf5
#
# Epoch 00110: loss improved from 0.61305 to 0.60839, saving model to model_part2.hdf5
#
# Epoch 00111: loss improved from 0.60839 to 0.60376, saving model to model_part2.hdf5
#
# Epoch 00112: loss improved from 0.60376 to 0.59924, saving model to model_part2.hdf5
#
# Epoch 00113: loss improved from 0.59924 to 0.59472, saving model to model_part2.hdf5
#
# Epoch 00114: loss improved from 0.59472 to 0.59044, saving model to model_part2.hdf5
#
# Epoch 00115: loss improved from 0.59044 to 0.58597, saving model to model_part2.hdf5
#
# Epoch 00116: loss improved from 0.58597 to 0.58231, saving model to model_part2.hdf5
#
# Epoch 00117: loss improved from 0.58231 to 0.57809, saving model to model_part2.hdf5
#
# Epoch 00118: loss improved from 0.57809 to 0.57411, saving model to model_part2.hdf5
#
# Epoch 00119: loss improved from 0.57411 to 0.56960, saving model to model_part2.hdf5
#
# Epoch 00120: loss improved from 0.56960 to 0.56587, saving model to model_part2.hdf5
#
# Epoch 00121: loss improved from 0.56587 to 0.56157, saving model to model_part2.hdf5
#
# Epoch 00122: loss improved from 0.56157 to 0.55785, saving model to model_part2.hdf5
#
# Epoch 00123: loss improved from 0.55785 to 0.55362, saving model to model_part2.hdf5
#
# Epoch 00124: loss improved from 0.55362 to 0.55002, saving model to model_part2.hdf5
#
# Epoch 00125: loss improved from 0.55002 to 0.54603, saving model to model_part2.hdf5
#
# Epoch 00126: loss improved from 0.54603 to 0.54246, saving model to model_part2.hdf5
#
# Epoch 00127: loss improved from 0.54246 to 0.53899, saving model to model_part2.hdf5
#
# Epoch 00128: loss improved from 0.53899 to 0.53530, saving model to model_part2.hdf5
#
# Epoch 00129: loss improved from 0.53530 to 0.52994, saving model to model_part2.hdf5
#
# Epoch 00130: loss improved from 0.52994 to 0.52522, saving model to model_part2.hdf5
#
# Epoch 00131: loss improved from 0.52522 to 0.52083, saving model to model_part2.hdf5
#
# Epoch 00132: loss improved from 0.52083 to 0.51682, saving model to model_part2.hdf5
#
# Epoch 00133: loss improved from 0.51682 to 0.51246, saving model to model_part2.hdf5
#
# Epoch 00134: loss improved from 0.51246 to 0.50830, saving model to model_part2.hdf5
#
# Epoch 00135: loss improved from 0.50830 to 0.50441, saving model to model_part2.hdf5
#
# Epoch 00136: loss improved from 0.50441 to 0.50110, saving model to model_part2.hdf5
#
# Epoch 00137: loss improved from 0.50110 to 0.49778, saving model to model_part2.hdf5
#
# Epoch 00138: loss improved from 0.49778 to 0.49314, saving model to model_part2.hdf5
#
# Epoch 00139: loss improved from 0.49314 to 0.48829, saving model to model_part2.hdf5
#
# Epoch 00140: loss improved from 0.48829 to 0.48463, saving model to model_part2.hdf5
#
# Epoch 00141: loss improved from 0.48463 to 0.48218, saving model to model_part2.hdf5
#
# Epoch 00142: loss improved from 0.48218 to 0.47753, saving model to model_part2.hdf5
#
# Epoch 00143: loss improved from 0.47753 to 0.47457, saving model to model_part2.hdf5
#
# Epoch 00144: loss improved from 0.47457 to 0.47039, saving model to model_part2.hdf5
#
# Epoch 00145: loss improved from 0.47039 to 0.46720, saving model to model_part2.hdf5
#
# Epoch 00146: loss improved from 0.46720 to 0.46377, saving model to model_part2.hdf5
#
# Epoch 00147: loss improved from 0.46377 to 0.46063, saving model to model_part2.hdf5
#
# Epoch 00148: loss improved from 0.46063 to 0.45730, saving model to model_part2.hdf5
#
# Epoch 00149: loss improved from 0.45730 to 0.45454, saving model to model_part2.hdf5
#
# Epoch 00150: loss improved from 0.45454 to 0.45204, saving model to model_part2.hdf5
#
# Epoch 00151: loss improved from 0.45204 to 0.44881, saving model to model_part2.hdf5
#
# Epoch 00152: loss improved from 0.44881 to 0.44591, saving model to model_part2.hdf5
#
# Epoch 00153: loss improved from 0.44591 to 0.44279, saving model to model_part2.hdf5
#
# Epoch 00154: loss improved from 0.44279 to 0.44016, saving model to model_part2.hdf5
#
# Epoch 00155: loss improved from 0.44016 to 0.43725, saving model to model_part2.hdf5
#
# Epoch 00156: loss improved from 0.43725 to 0.43468, saving model to model_part2.hdf5
#
# Epoch 00157: loss improved from 0.43468 to 0.43196, saving model to model_part2.hdf5
#
# Epoch 00158: loss improved from 0.43196 to 0.42951, saving model to model_part2.hdf5
#
# Epoch 00159: loss improved from 0.42951 to 0.42681, saving model to model_part2.hdf5
#
# Epoch 00160: loss improved from 0.42681 to 0.42466, saving model to model_part2.hdf5
#
# Epoch 00161: loss improved from 0.42466 to 0.42192, saving model to model_part2.hdf5
#
# Epoch 00162: loss improved from 0.42192 to 0.41981, saving model to model_part2.hdf5
#
# Epoch 00163: loss improved from 0.41981 to 0.41711, saving model to model_part2.hdf5
#
# Epoch 00164: loss improved from 0.41711 to 0.41512, saving model to model_part2.hdf5
#
# Epoch 00165: loss improved from 0.41512 to 0.41214, saving model to model_part2.hdf5
#
# Epoch 00166: loss improved from 0.41214 to 0.40952, saving model to model_part2.hdf5
#
# Epoch 00167: loss improved from 0.40952 to 0.40710, saving model to model_part2.hdf5
#
# Epoch 00168: loss improved from 0.40710 to 0.40488, saving model to model_part2.hdf5
#
# Epoch 00169: loss improved from 0.40488 to 0.40239, saving model to model_part2.hdf5
#
# Epoch 00170: loss improved from 0.40239 to 0.39996, saving model to model_part2.hdf5
#
# Epoch 00171: loss improved from 0.39996 to 0.39773, saving model to model_part2.hdf5
#
# Epoch 00172: loss improved from 0.39773 to 0.39541, saving model to model_part2.hdf5
#
# Epoch 00173: loss improved from 0.39541 to 0.39341, saving model to model_part2.hdf5
#
# Epoch 00174: loss improved from 0.39341 to 0.39137, saving model to model_part2.hdf5
#
# Epoch 00175: loss improved from 0.39137 to 0.38968, saving model to model_part2.hdf5
#
# Epoch 00176: loss improved from 0.38968 to 0.38873, saving model to model_part2.hdf5
#
# Epoch 00177: loss improved from 0.38873 to 0.38580, saving model to model_part2.hdf5
#
# Epoch 00178: loss improved from 0.38580 to 0.38335, saving model to model_part2.hdf5
#
# Epoch 00179: loss improved from 0.38335 to 0.37992, saving model to model_part2.hdf5
#
# Epoch 00180: loss improved from 0.37992 to 0.37776, saving model to model_part2.hdf5
#
# Epoch 00181: loss improved from 0.37776 to 0.37515, saving model to model_part2.hdf5
#
# Epoch 00182: loss improved from 0.37515 to 0.37293, saving model to model_part2.hdf5
#
# Epoch 00183: loss improved from 0.37293 to 0.37056, saving model to model_part2.hdf5
#
# Epoch 00184: loss improved from 0.37056 to 0.36843, saving model to model_part2.hdf5
#
# Epoch 00185: loss improved from 0.36843 to 0.36621, saving model to model_part2.hdf5
#
# Epoch 00186: loss improved from 0.36621 to 0.36416, saving model to model_part2.hdf5
#
# Epoch 00187: loss improved from 0.36416 to 0.36210, saving model to model_part2.hdf5
#
# Epoch 00188: loss improved from 0.36210 to 0.36121, saving model to model_part2.hdf5
#
# Epoch 00189: loss improved from 0.36121 to 0.35917, saving model to model_part2.hdf5
#
# Epoch 00190: loss improved from 0.35917 to 0.35804, saving model to model_part2.hdf5
#
# Epoch 00191: loss improved from 0.35804 to 0.35524, saving model to model_part2.hdf5
#
# Epoch 00192: loss improved from 0.35524 to 0.35338, saving model to model_part2.hdf5
#
# Epoch 00193: loss improved from 0.35338 to 0.35046, saving model to model_part2.hdf5
#
# Epoch 00194: loss improved from 0.35046 to 0.34832, saving model to model_part2.hdf5
#
# Epoch 00195: loss improved from 0.34832 to 0.34614, saving model to model_part2.hdf5
#
# Epoch 00196: loss improved from 0.34614 to 0.34403, saving model to model_part2.hdf5
#
# Epoch 00197: loss improved from 0.34403 to 0.34215, saving model to model_part2.hdf5
# Epoch 00198: loss improved from 0.34215 to 0.34034, saving model to model_part2.hdf5
#
# Epoch 00199: loss improved from 0.34034 to 0.33870, saving model to model_part2.hdf5
#
# Epoch 00200: loss improved from 0.33870 to 0.33805, saving model to model_part2.hdf5
#
# Epoch 00201: loss improved from 0.33805 to 0.33653, saving model to model_part2.hdf5
#
# Epoch 00202: loss improved from 0.33653 to 0.33513, saving model to model_part2.hdf5
#
# Epoch 00203: loss improved from 0.33513 to 0.33249, saving model to model_part2.hdf5
#
# Epoch 00204: loss improved from 0.33249 to 0.33031, saving model to model_part2.hdf5
#
# Epoch 00205: loss improved from 0.33031 to 0.32764, saving model to model_part2.hdf5
#
# Epoch 00206: loss improved from 0.32764 to 0.32548, saving model to model_part2.hdf5
#
# Epoch 00207: loss improved from 0.32548 to 0.32332, saving model to model_part2.hdf5
#
# Epoch 00208: loss improved from 0.32332 to 0.32143, saving model to model_part2.hdf5
#
# Epoch 00209: loss improved from 0.32143 to 0.31942, saving model to model_part2.hdf5
#
# Epoch 00210: loss improved from 0.31942 to 0.31769, saving model to model_part2.hdf5
#
# Epoch 00211: loss improved from 0.31769 to 0.31590, saving model to model_part2.hdf5
#
# Epoch 00212: loss improved from 0.31590 to 0.31507, saving model to model_part2.hdf5
#
# Epoch 00213: loss improved from 0.31507 to 0.31338, saving model to model_part2.hdf5
#
# Epoch 00214: loss improved from 0.31338 to 0.31259, saving model to model_part2.hdf5
#
# Epoch 00215: loss improved from 0.31259 to 0.31033, saving model to model_part2.hdf5
#
# Epoch 00216: loss improved from 0.31033 to 0.30842, saving model to model_part2.hdf5
#
# Epoch 00217: loss improved from 0.30842 to 0.30590, saving model to model_part2.hdf5
#
# Epoch 00218: loss improved from 0.30590 to 0.30414, saving model to model_part2.hdf5
#
# Epoch 00219: loss improved from 0.30414 to 0.30190, saving model to model_part2.hdf5
#
# Epoch 00220: loss improved from 0.30190 to 0.30070, saving model to model_part2.hdf5
#
# Epoch 00221: loss improved from 0.30070 to 0.29862, saving model to model_part2.hdf5
#
# Epoch 00222: loss improved from 0.29862 to 0.29751, saving model to model_part2.hdf5
#
# Epoch 00223: loss improved from 0.29751 to 0.29551, saving model to model_part2.hdf5
#
# Epoch 00224: loss improved from 0.29551 to 0.29458, saving model to model_part2.hdf5
#
# Epoch 00225: loss improved from 0.29458 to 0.29259, saving model to model_part2.hdf5
#
# Epoch 00226: loss improved from 0.29259 to 0.29145, saving model to model_part2.hdf5
#
# Epoch 00227: loss improved from 0.29145 to 0.28924, saving model to model_part2.hdf5
#
# Epoch 00228: loss improved from 0.28924 to 0.28804, saving model to model_part2.hdf5
#
# Epoch 00229: loss improved from 0.28804 to 0.28588, saving model to model_part2.hdf5
#
# Epoch 00230: loss improved from 0.28588 to 0.28483, saving model to model_part2.hdf5
#
# Epoch 00231: loss improved from 0.28483 to 0.28276, saving model to model_part2.hdf5
#
# Epoch 00232: loss improved from 0.28276 to 0.28149, saving model to model_part2.hdf5
#
# Epoch 00233: loss improved from 0.28149 to 0.27965, saving model to model_part2.hdf5
#
# Epoch 00234: loss improved from 0.27965 to 0.27868, saving model to model_part2.hdf5
#
# Epoch 00235: loss improved from 0.27868 to 0.27689, saving model to model_part2.hdf5
#
# Epoch 00236: loss improved from 0.27689 to 0.27610, saving model to model_part2.hdf5
#
# Epoch 00237: loss improved from 0.27610 to 0.27422, saving model to model_part2.hdf5
#
# Epoch 00238: loss improved from 0.27422 to 0.27314, saving model to model_part2.hdf5
#
# Epoch 00239: loss improved from 0.27314 to 0.27112, saving model to model_part2.hdf5
#
# Epoch 00240: loss improved from 0.27112 to 0.26998, saving model to model_part2.hdf5
#
# Epoch 00241: loss improved from 0.26998 to 0.26790, saving model to model_part2.hdf5
#
# Epoch 00242: loss improved from 0.26790 to 0.26673, saving model to model_part2.hdf5
#
# Epoch 00243: loss improved from 0.26673 to 0.26493, saving model to model_part2.hdf5
#
# Epoch 00244: loss improved from 0.26493 to 0.26385, saving model to model_part2.hdf5
#
# Epoch 00245: loss improved from 0.26385 to 0.26207, saving model to model_part2.hdf5
#
# Epoch 00246: loss improved from 0.26207 to 0.26110, saving model to model_part2.hdf5
#
# Epoch 00247: loss improved from 0.26110 to 0.25930, saving model to model_part2.hdf5
#
# Epoch 00248: loss improved from 0.25930 to 0.25838, saving model to model_part2.hdf5
#
# Epoch 00249: loss improved from 0.25838 to 0.25652, saving model to model_part2.hdf5
#
# Epoch 00250: loss improved from 0.25652 to 0.25562, saving model to model_part2.hdf5
#
# Epoch 00251: loss improved from 0.25562 to 0.25368, saving model to model_part2.hdf5
#
# Epoch 00252: loss improved from 0.25368 to 0.25266, saving model to model_part2.hdf5
#
# Epoch 00253: loss improved from 0.25266 to 0.25070, saving model to model_part2.hdf5
#
# Epoch 00254: loss improved from 0.25070 to 0.24965, saving model to model_part2.hdf5
#
# Epoch 00255: loss improved from 0.24965 to 0.24780, saving model to model_part2.hdf5
#
# Epoch 00256: loss improved from 0.24780 to 0.24690, saving model to model_part2.hdf5
#
# Epoch 00257: loss improved from 0.24690 to 0.24507, saving model to model_part2.hdf5
#
# Epoch 00258: loss improved from 0.24507 to 0.24409, saving model to model_part2.hdf5
#
# Epoch 00259: loss improved from 0.24409 to 0.24226, saving model to model_part2.hdf5
#
# Epoch 00260: loss improved from 0.24226 to 0.24121, saving model to model_part2.hdf5
#
# Epoch 00261: loss improved from 0.24121 to 0.23952, saving model to model_part2.hdf5
#
# Epoch 00262: loss improved from 0.23952 to 0.23867, saving model to model_part2.hdf5
#
# Epoch 00263: loss improved from 0.23867 to 0.23691, saving model to model_part2.hdf5
#
# Epoch 00264: loss improved from 0.23691 to 0.23561, saving model to model_part2.hdf5
#
# Epoch 00265: loss improved from 0.23561 to 0.23387, saving model to model_part2.hdf5
#
# Epoch 00266: loss improved from 0.23387 to 0.23310, saving model to model_part2.hdf5
#
# Epoch 00267: loss improved from 0.23310 to 0.23119, saving model to model_part2.hdf5
#
# Epoch 00268: loss improved from 0.23119 to 0.23036, saving model to model_part2.hdf5
#
# Epoch 00269: loss improved from 0.23036 to 0.22827, saving model to model_part2.hdf5
#
# Epoch 00270: loss improved from 0.22827 to 0.22705, saving model to model_part2.hdf5
#
# Epoch 00271: loss improved from 0.22705 to 0.22512, saving model to model_part2.hdf5
#
# Epoch 00272: loss improved from 0.22512 to 0.22401, saving model to model_part2.hdf5
#
# Epoch 00273: loss improved from 0.22401 to 0.22196, saving model to model_part2.hdf5
#
# Epoch 00274: loss improved from 0.22196 to 0.22104, saving model to model_part2.hdf5
#
# Epoch 00275: loss improved from 0.22104 to 0.21941, saving model to model_part2.hdf5
#
# Epoch 00276: loss improved from 0.21941 to 0.21843, saving model to model_part2.hdf5
#
# Epoch 00277: loss improved from 0.21843 to 0.21655, saving model to model_part2.hdf5
#
# Epoch 00278: loss improved from 0.21655 to 0.21579, saving model to model_part2.hdf5
#
# Epoch 00279: loss improved from 0.21579 to 0.21414, saving model to model_part2.hdf5
#
# Epoch 00280: loss improved from 0.21414 to 0.21299, saving model to model_part2.hdf5
#
# Epoch 00281: loss improved from 0.21299 to 0.21100, saving model to model_part2.hdf5
#
# Epoch 00282: loss improved from 0.21100 to 0.20996, saving model to model_part2.hdf5
#
# Epoch 00283: loss improved from 0.20996 to 0.20806, saving model to model_part2.hdf5
#
# Epoch 00284: loss improved from 0.20806 to 0.20714, saving model to model_part2.hdf5
#
# Epoch 00285: loss improved from 0.20714 to 0.20557, saving model to model_part2.hdf5
#
# Epoch 00286: loss improved from 0.20557 to 0.20456, saving model to model_part2.hdf5
#
# Epoch 00287: loss improved from 0.20456 to 0.20262, saving model to model_part2.hdf5
#
# Epoch 00288: loss improved from 0.20262 to 0.20142, saving model to model_part2.hdf5
#
# Epoch 00289: loss improved from 0.20142 to 0.19960, saving model to model_part2.hdf5
#
# Epoch 00290: loss improved from 0.19960 to 0.19860, saving model to model_part2.hdf5
#
# Epoch 00291: loss improved from 0.19860 to 0.19722, saving model to model_part2.hdf5
#
# Epoch 00292: loss improved from 0.19722 to 0.19621, saving model to model_part2.hdf5
#
# Epoch 00293: loss improved from 0.19621 to 0.19432, saving model to model_part2.hdf5
#
# Epoch 00294: loss improved from 0.19432 to 0.19314, saving model to model_part2.hdf5
#
# Epoch 00295: loss improved from 0.19314 to 0.19124, saving model to model_part2.hdf5
#
# Epoch 00296: loss improved from 0.19124 to 0.19027, saving model to model_part2.hdf5
#
# Epoch 00297: loss improved from 0.19027 to 0.18845, saving model to model_part2.hdf5
#
# Epoch 00298: loss improved from 0.18845 to 0.18746, saving model to model_part2.hdf5
#
# Epoch 00299: loss improved from 0.18746 to 0.18571, saving model to model_part2.hdf5
# Epoch 00300: loss improved from 0.18571 to 0.18484, saving model to model_part2.hdf5
#
# Epoch 00301: loss improved from 0.18484 to 0.18301, saving model to model_part2.hdf5
#
# Epoch 00302: loss improved from 0.18301 to 0.18198, saving model to model_part2.hdf5
#
# Epoch 00303: loss improved from 0.18198 to 0.18006, saving model to model_part2.hdf5
#
# Epoch 00304: loss improved from 0.18006 to 0.17911, saving model to model_part2.hdf5
#
# Epoch 00305: loss improved from 0.17911 to 0.17730, saving model to model_part2.hdf5
#
# Epoch 00306: loss improved from 0.17730 to 0.17634, saving model to model_part2.hdf5
#
# Epoch 00307: loss improved from 0.17634 to 0.17451, saving model to model_part2.hdf5
#
# Epoch 00308: loss improved from 0.17451 to 0.17378, saving model to model_part2.hdf5
#
# Epoch 00309: loss improved from 0.17378 to 0.17187, saving model to model_part2.hdf5
#
# Epoch 00310: loss improved from 0.17187 to 0.17091, saving model to model_part2.hdf5
#
# Epoch 00311: loss improved from 0.17091 to 0.16899, saving model to model_part2.hdf5
#
# Epoch 00312: loss improved from 0.16899 to 0.16807, saving model to model_part2.hdf5
#
# Epoch 00313: loss improved from 0.16807 to 0.16619, saving model to model_part2.hdf5
#
# Epoch 00314: loss improved from 0.16619 to 0.16542, saving model to model_part2.hdf5
#
# Epoch 00315: loss improved from 0.16542 to 0.16351, saving model to model_part2.hdf5
#
# Epoch 00316: loss improved from 0.16351 to 0.16296, saving model to model_part2.hdf5
#
# Epoch 00317: loss improved from 0.16296 to 0.16089, saving model to model_part2.hdf5
#
# Epoch 00318: loss improved from 0.16089 to 0.16013, saving model to model_part2.hdf5
#
# Epoch 00319: loss improved from 0.16013 to 0.15810, saving model to model_part2.hdf5
#
# Epoch 00320: loss improved from 0.15810 to 0.15751, saving model to model_part2.hdf5
#
# Epoch 00321: loss improved from 0.15751 to 0.15551, saving model to model_part2.hdf5
#
# Epoch 00322: loss improved from 0.15551 to 0.15484, saving model to model_part2.hdf5
#
# Epoch 00323: loss improved from 0.15484 to 0.15280, saving model to model_part2.hdf5
#
# Epoch 00324: loss improved from 0.15280 to 0.15243, saving model to model_part2.hdf5
#
# Epoch 00325: loss improved from 0.15243 to 0.15024, saving model to model_part2.hdf5
#
# Epoch 00326: loss improved from 0.15024 to 0.14985, saving model to model_part2.hdf5
#
# Epoch 00327: loss improved from 0.14985 to 0.14759, saving model to model_part2.hdf5
#
# Epoch 00328: loss improved from 0.14759 to 0.14645, saving model to model_part2.hdf5
#
# Epoch 00329: loss improved from 0.14645 to 0.14468, saving model to model_part2.hdf5
#
# Epoch 00330: loss improved from 0.14468 to 0.14388, saving model to model_part2.hdf5
#
# Epoch 00331: loss improved from 0.14388 to 0.14220, saving model to model_part2.hdf5
#
# Epoch 00332: loss improved from 0.14220 to 0.14136, saving model to model_part2.hdf5
#
# Epoch 00333: loss improved from 0.14136 to 0.13986, saving model to model_part2.hdf5
#
# Epoch 00334: loss did not improve from 0.13986
#
# Epoch 00335: loss improved from 0.13986 to 0.13810, saving model to model_part2.hdf5
#
# Epoch 00336: loss improved from 0.13810 to 0.13792, saving model to model_part2.hdf5
#
# Epoch 00337: loss improved from 0.13792 to 0.13537, saving model to model_part2.hdf5
#
# Epoch 00338: loss improved from 0.13537 to 0.13365, saving model to model_part2.hdf5
#
# Epoch 00339: loss improved from 0.13365 to 0.13193, saving model to model_part2.hdf5
#
# Epoch 00340: loss improved from 0.13193 to 0.13067, saving model to model_part2.hdf5
#
# Epoch 00341: loss improved from 0.13067 to 0.12927, saving model to model_part2.hdf5
#
# Epoch 00342: loss improved from 0.12927 to 0.12826, saving model to model_part2.hdf5
#
# Epoch 00343: loss improved from 0.12826 to 0.12703, saving model to model_part2.hdf5
#
# Epoch 00344: loss improved from 0.12703 to 0.12616, saving model to model_part2.hdf5
#
# Epoch 00345: loss improved from 0.12616 to 0.12513, saving model to model_part2.hdf5
#
# Epoch 00346: loss did not improve from 0.12513
#
# Epoch 00347: loss improved from 0.12513 to 0.12409, saving model to model_part2.hdf5
#
# Epoch 00348: loss improved from 0.12409 to 0.12394, saving model to model_part2.hdf5
#
# Epoch 00349: loss improved from 0.12394 to 0.12101, saving model to model_part2.hdf5
#
# Epoch 00350: loss improved from 0.12101 to 0.11977, saving model to model_part2.hdf5
#
# Epoch 00351: loss improved from 0.11977 to 0.11769, saving model to model_part2.hdf5
#
# Epoch 00352: loss improved from 0.11769 to 0.11612, saving model to model_part2.hdf5
#
# Epoch 00353: loss improved from 0.11612 to 0.11479, saving model to model_part2.hdf5
# Testing the model
# 45/45 [==============================] - 0s 832us/step
# ====================================================
# Percent Training Size  0.4
# Training the Model
#
# Epoch 00001: loss improved from inf to 1.09850, saving model to model_part2.hdf5
#
# Epoch 00002: loss improved from 1.09850 to 1.09426, saving model to model_part2.hdf5
#
# Epoch 00003: loss improved from 1.09426 to 1.09236, saving model to model_part2.hdf5
#
# Epoch 00004: loss improved from 1.09236 to 1.09164, saving model to model_part2.hdf5
#
# Epoch 00005: loss improved from 1.09164 to 1.08992, saving model to model_part2.hdf5
#
# ...
#
# Epoch 00458: loss improved from 0.46213 to 0.46180, saving model to model_part2.hdf5
#
# Epoch 00459: loss improved from 0.46180 to 0.46147, saving model to model_part2.hdf5
#
# Epoch 00460: loss improved from 0.46147 to 0.46124, saving model to model_part2.hdf5
#
# Epoch 00461: loss improved from 0.46124 to 0.46104, saving model to model_part2.hdf5
# Epoch 00462: loss improved from 0.46104 to 0.46086, saving model to model_part2.hdf5
#
# Epoch 00463: loss improved from 0.46086 to 0.46057, saving model to model_part2.hdf5
#
# Epoch 00464: loss improved from 0.46057 to 0.46046, saving model to model_part2.hdf5
#
# Epoch 00465: loss improved from 0.46046 to 0.46029, saving model to model_part2.hdf5
#
# Epoch 00466: loss improved from 0.46029 to 0.46005, saving model to model_part2.hdf5
#
# Epoch 00467: loss improved from 0.46005 to 0.45985, saving model to model_part2.hdf5
#
# Epoch 00468: loss improved from 0.45985 to 0.45969, saving model to model_part2.hdf5
#
# Epoch 00469: loss improved from 0.45969 to 0.45944, saving model to model_part2.hdf5
#
# Epoch 00470: loss improved from 0.45944 to 0.45936, saving model to model_part2.hdf5
#
# Epoch 00471: loss improved from 0.45936 to 0.45914, saving model to model_part2.hdf5
#
# Epoch 00472: loss improved from 0.45914 to 0.45892, saving model to model_part2.hdf5
#
# Epoch 00473: loss improved from 0.45892 to 0.45869, saving model to model_part2.hdf5
#
# Epoch 00474: loss did not improve from 0.45869
#
# Epoch 00475: loss improved from 0.45869 to 0.45843, saving model to model_part2.hdf5
#
# Epoch 00476: loss improved from 0.45843 to 0.45682, saving model to model_part2.hdf5
#
# Epoch 00477: loss improved from 0.45682 to 0.45158, saving model to model_part2.hdf5
#
# Epoch 00478: loss improved from 0.45158 to 0.44966, saving model to model_part2.hdf5
#
# Epoch 00479: loss improved from 0.44966 to 0.44713, saving model to model_part2.hdf5
#
# Epoch 00480: loss improved from 0.44713 to 0.44535, saving model to model_part2.hdf5
#
# Epoch 00481: loss improved from 0.44535 to 0.44289, saving model to model_part2.hdf5
#
# Epoch 00482: loss improved from 0.44289 to 0.44071, saving model to model_part2.hdf5
#
# Epoch 00483: loss improved from 0.44071 to 0.44000, saving model to model_part2.hdf5
#
# Epoch 00484: loss improved from 0.44000 to 0.43698, saving model to model_part2.hdf5
#
# Epoch 00485: loss did not improve from 0.43698
#
# Epoch 00486: loss improved from 0.43698 to 0.43643, saving model to model_part2.hdf5
#
# Epoch 00487: loss improved from 0.43643 to 0.43165, saving model to model_part2.hdf5
#
# Epoch 00488: loss improved from 0.43165 to 0.43137, saving model to model_part2.hdf5
#
# Epoch 00489: loss did not improve from 0.43137
#
# Epoch 00490: loss improved from 0.43137 to 0.42793, saving model to model_part2.hdf5
#
# Epoch 00491: loss improved from 0.42793 to 0.42716, saving model to model_part2.hdf5
#
# Epoch 00492: loss improved from 0.42716 to 0.42604, saving model to model_part2.hdf5
# Testing the model
# 45/45 [==============================] - 0s 2ms/step
# ====================================================
# Percent Training Size  0.9
# Training the Model
#
# Epoch 00001: loss improved from inf to 1.09769, saving model to model_part2.hdf5
#
# Epoch 00002: loss improved from 1.09769 to 1.09581, saving model to model_part2.hdf5
#
# Epoch 00003: loss improved from 1.09581 to 1.09457, saving model to model_part2.hdf5
#
# Epoch 00004: loss improved from 1.09457 to 1.09337, saving model to model_part2.hdf5
#
# Epoch 00005: loss improved from 1.09337 to 1.09212, saving model to model_part2.hdf5
#
# Epoch 00006: loss improved from 1.09212 to 1.09085, saving model to model_part2.hdf5
#
# Epoch 00007: loss improved from 1.09085 to 1.08951, saving model to model_part2.hdf5
#
# Epoch 00008: loss improved from 1.08951 to 1.08792, saving model to model_part2.hdf5
#
# Epoch 00009: loss improved from 1.08792 to 1.08640, saving model to model_part2.hdf5
#
# Epoch 00010: loss improved from 1.08640 to 1.08484, saving model to model_part2.hdf5
#
# Epoch 00011: loss improved from 1.08484 to 1.08318, saving model to model_part2.hdf5
#
# Epoch 00012: loss improved from 1.08318 to 1.08156, saving model to model_part2.hdf5
#
# Epoch 00013: loss improved from 1.08156 to 1.07951, saving model to model_part2.hdf5
#
# Epoch 00014: loss improved from 1.07951 to 1.07776, saving model to model_part2.hdf5
#
# Epoch 00015: loss improved from 1.07776 to 1.07601, saving model to model_part2.hdf5
#
# Epoch 00016: loss improved from 1.07601 to 1.07429, saving model to model_part2.hdf5
#
# Epoch 00017: loss improved from 1.07429 to 1.07259, saving model to model_part2.hdf5
#
# Epoch 00018: loss improved from 1.07259 to 1.07016, saving model to model_part2.hdf5
#
# Epoch 00019: loss improved from 1.07016 to 1.06802, saving model to model_part2.hdf5
#
# Epoch 00020: loss improved from 1.06802 to 1.06571, saving model to model_part2.hdf5
#
# Epoch 00021: loss improved from 1.06571 to 1.06344, saving model to model_part2.hdf5
#
# Epoch 00022: loss improved from 1.06344 to 1.06097, saving model to model_part2.hdf5
#
# Epoch 00023: loss improved from 1.06097 to 1.05824, saving model to model_part2.hdf5
#
# Epoch 00024: loss improved from 1.05824 to 1.05577, saving model to model_part2.hdf5
#
# Epoch 00025: loss improved from 1.05577 to 1.05328, saving model to model_part2.hdf5
#
# Epoch 00026: loss improved from 1.05328 to 1.05028, saving model to model_part2.hdf5
#
# Epoch 00027: loss improved from 1.05028 to 1.04745, saving model to model_part2.hdf5
#
# Epoch 00028: loss improved from 1.04745 to 1.04379, saving model to model_part2.hdf5
#
# Epoch 00029: loss improved from 1.04379 to 1.04057, saving model to model_part2.hdf5
#
# Epoch 00030: loss improved from 1.04057 to 1.03734, saving model to model_part2.hdf5
#
# Epoch 00031: loss improved from 1.03734 to 1.03324, saving model to model_part2.hdf5
#
# Epoch 00032: loss improved from 1.03324 to 1.03025, saving model to model_part2.hdf5
#
# Epoch 00033: loss improved from 1.03025 to 1.02629, saving model to model_part2.hdf5
#
# Epoch 00034: loss improved from 1.02629 to 1.02257, saving model to model_part2.hdf5
#
# Epoch 00035: loss improved from 1.02257 to 1.01852, saving model to model_part2.hdf5
#
# Epoch 00036: loss improved from 1.01852 to 1.01470, saving model to model_part2.hdf5
#
# Epoch 00037: loss improved from 1.01470 to 1.01069, saving model to model_part2.hdf5
#
# Epoch 00038: loss improved from 1.01069 to 1.00581, saving model to model_part2.hdf5
#
# Epoch 00039: loss improved from 1.00581 to 1.00127, saving model to model_part2.hdf5
#
# Epoch 00040: loss improved from 1.00127 to 0.99610, saving model to model_part2.hdf5
#
# Epoch 00041: loss improved from 0.99610 to 0.99178, saving model to model_part2.hdf5
#
# Epoch 00042: loss improved from 0.99178 to 0.98731, saving model to model_part2.hdf5
#
# Epoch 00043: loss improved from 0.98731 to 0.98158, saving model to model_part2.hdf5
#
# Epoch 00044: loss improved from 0.98158 to 0.97626, saving model to model_part2.hdf5
#
# Epoch 00045: loss improved from 0.97626 to 0.97173, saving model to model_part2.hdf5
#
# Epoch 00046: loss improved from 0.97173 to 0.96747, saving model to model_part2.hdf5
#
# Epoch 00047: loss improved from 0.96747 to 0.96189, saving model to model_part2.hdf5
#
# Epoch 00048: loss improved from 0.96189 to 0.95703, saving model to model_part2.hdf5
#
# Epoch 00049: loss improved from 0.95703 to 0.95242, saving model to model_part2.hdf5
#
# Epoch 00050: loss improved from 0.95242 to 0.94778, saving model to model_part2.hdf5
#
# Epoch 00051: loss improved from 0.94778 to 0.94267, saving model to model_part2.hdf5
#
# Epoch 00052: loss improved from 0.94267 to 0.93674, saving model to model_part2.hdf5
#
# Epoch 00053: loss improved from 0.93674 to 0.93193, saving model to model_part2.hdf5
#
# Epoch 00054: loss improved from 0.93193 to 0.92530, saving model to model_part2.hdf5
#
# Epoch 00055: loss improved from 0.92530 to 0.91868, saving model to model_part2.hdf5
#
# Epoch 00056: loss improved from 0.91868 to 0.91271, saving model to model_part2.hdf5
#
# Epoch 00057: loss improved from 0.91271 to 0.90610, saving model to model_part2.hdf5
#
# Epoch 00058: loss improved from 0.90610 to 0.89843, saving model to model_part2.hdf5
#
# Epoch 00059: loss improved from 0.89843 to 0.89027, saving model to model_part2.hdf5
#
# Epoch 00060: loss improved from 0.89027 to 0.88220, saving model to model_part2.hdf5
#
# Epoch 00061: loss improved from 0.88220 to 0.87367, saving model to model_part2.hdf5
#
# Epoch 00062: loss improved from 0.87367 to 0.86500, saving model to model_part2.hdf5
#
# Epoch 00063: loss improved from 0.86500 to 0.85650, saving model to model_part2.hdf5
#
# Epoch 00064: loss improved from 0.85650 to 0.84717, saving model to model_part2.hdf5
#
# Epoch 00065: loss improved from 0.84717 to 0.83857, saving model to model_part2.hdf5
#
# Epoch 00066: loss improved from 0.83857 to 0.82954, saving model to model_part2.hdf5
#
# Epoch 00067: loss improved from 0.82954 to 0.82027, saving model to model_part2.hdf5
#
# Epoch 00068: loss improved from 0.82027 to 0.81095, saving model to model_part2.hdf5
#
# Epoch 00069: loss improved from 0.81095 to 0.80253, saving model to model_part2.hdf5
#
# Epoch 00070: loss improved from 0.80253 to 0.79276, saving model to model_part2.hdf5
#
# Epoch 00071: loss improved from 0.79276 to 0.78363, saving model to model_part2.hdf5
# Epoch 00072: loss improved from 0.78363 to 0.77604, saving model to model_part2.hdf5
#
# Epoch 00073: loss improved from 0.77604 to 0.76630, saving model to model_part2.hdf5
#
# Epoch 00074: loss improved from 0.76630 to 0.75380, saving model to model_part2.hdf5
#
# Epoch 00075: loss improved from 0.75380 to 0.74207, saving model to model_part2.hdf5
#
# Epoch 00076: loss improved from 0.74207 to 0.73094, saving model to model_part2.hdf5
#
# Epoch 00077: loss improved from 0.73094 to 0.71939, saving model to model_part2.hdf5
#
# Epoch 00078: loss improved from 0.71939 to 0.70665, saving model to model_part2.hdf5
#
# Epoch 00079: loss improved from 0.70665 to 0.69619, saving model to model_part2.hdf5
#
# Epoch 00080: loss improved from 0.69619 to 0.68557, saving model to model_part2.hdf5
#
# Epoch 00081: loss improved from 0.68557 to 0.67288, saving model to model_part2.hdf5
#
# Epoch 00082: loss improved from 0.67288 to 0.66123, saving model to model_part2.hdf5
#
# Epoch 00083: loss improved from 0.66123 to 0.65041, saving model to model_part2.hdf5
#
# Epoch 00084: loss improved from 0.65041 to 0.63865, saving model to model_part2.hdf5
#
# Epoch 00085: loss improved from 0.63865 to 0.62777, saving model to model_part2.hdf5
#
# Epoch 00086: loss improved from 0.62777 to 0.61608, saving model to model_part2.hdf5
#
# Epoch 00087: loss improved from 0.61608 to 0.60566, saving model to model_part2.hdf5
#
# Epoch 00088: loss improved from 0.60566 to 0.59764, saving model to model_part2.hdf5
#
# Epoch 00089: loss improved from 0.59764 to 0.58420, saving model to model_part2.hdf5
#
# Epoch 00090: loss improved from 0.58420 to 0.57673, saving model to model_part2.hdf5
#
# Epoch 00091: loss improved from 0.57673 to 0.56486, saving model to model_part2.hdf5
#
# Epoch 00092: loss improved from 0.56486 to 0.55686, saving model to model_part2.hdf5
#
# Epoch 00093: loss improved from 0.55686 to 0.55012, saving model to model_part2.hdf5
#
# Epoch 00094: loss improved from 0.55012 to 0.54018, saving model to model_part2.hdf5
#
# Epoch 00095: loss improved from 0.54018 to 0.53006, saving model to model_part2.hdf5
#
# Epoch 00096: loss improved from 0.53006 to 0.52184, saving model to model_part2.hdf5
#
# Epoch 00097: loss improved from 0.52184 to 0.51492, saving model to model_part2.hdf5
#
# Epoch 00098: loss improved from 0.51492 to 0.50779, saving model to model_part2.hdf5
#
# Epoch 00099: loss improved from 0.50779 to 0.49785, saving model to model_part2.hdf5
#
# Epoch 00100: loss improved from 0.49785 to 0.48834, saving model to model_part2.hdf5
#
# Epoch 00101: loss improved from 0.48834 to 0.48209, saving model to model_part2.hdf5
#
# Epoch 00102: loss improved from 0.48209 to 0.47446, saving model to model_part2.hdf5
#
# Epoch 00103: loss improved from 0.47446 to 0.46371, saving model to model_part2.hdf5
#
# Epoch 00104: loss improved from 0.46371 to 0.45581, saving model to model_part2.hdf5
#
# Epoch 00105: loss improved from 0.45581 to 0.44915, saving model to model_part2.hdf5
#
# Epoch 00106: loss improved from 0.44915 to 0.43979, saving model to model_part2.hdf5
#
# Epoch 00107: loss improved from 0.43979 to 0.43324, saving model to model_part2.hdf5
#
# Epoch 00108: loss improved from 0.43324 to 0.42960, saving model to model_part2.hdf5
#
# Epoch 00109: loss improved from 0.42960 to 0.41788, saving model to model_part2.hdf5
#
# Epoch 00110: loss improved from 0.41788 to 0.41131, saving model to model_part2.hdf5
#
# Epoch 00111: loss improved from 0.41131 to 0.40717, saving model to model_part2.hdf5
#
# Epoch 00112: loss improved from 0.40717 to 0.39790, saving model to model_part2.hdf5
#
# Epoch 00113: loss improved from 0.39790 to 0.39355, saving model to model_part2.hdf5
#
# Epoch 00114: loss improved from 0.39355 to 0.38621, saving model to model_part2.hdf5
#
# Epoch 00115: loss improved from 0.38621 to 0.37743, saving model to model_part2.hdf5
#
# Epoch 00116: loss improved from 0.37743 to 0.37414, saving model to model_part2.hdf5
#
# Epoch 00117: loss improved from 0.37414 to 0.37000, saving model to model_part2.hdf5
#
# Epoch 00118: loss improved from 0.37000 to 0.35835, saving model to model_part2.hdf5
#
# Epoch 00119: loss improved from 0.35835 to 0.35782, saving model to model_part2.hdf5
#
# Epoch 00120: loss improved from 0.35782 to 0.35251, saving model to model_part2.hdf5
#
# Epoch 00121: loss improved from 0.35251 to 0.34322, saving model to model_part2.hdf5
#
# Epoch 00122: loss improved from 0.34322 to 0.33844, saving model to model_part2.hdf5
#
# Epoch 00123: loss improved from 0.33844 to 0.33125, saving model to model_part2.hdf5
#
# Epoch 00124: loss improved from 0.33125 to 0.32562, saving model to model_part2.hdf5
#
# Epoch 00125: loss improved from 0.32562 to 0.32135, saving model to model_part2.hdf5
#
# Epoch 00126: loss improved from 0.32135 to 0.31820, saving model to model_part2.hdf5
#
# Epoch 00127: loss improved from 0.31820 to 0.31057, saving model to model_part2.hdf5
#
# Epoch 00128: loss improved from 0.31057 to 0.30487, saving model to model_part2.hdf5
#
# Epoch 00129: loss improved from 0.30487 to 0.29913, saving model to model_part2.hdf5
#
# Epoch 00130: loss improved from 0.29913 to 0.29652, saving model to model_part2.hdf5
#
# Epoch 00131: loss improved from 0.29652 to 0.28988, saving model to model_part2.hdf5
#
# Epoch 00132: loss improved from 0.28988 to 0.28820, saving model to model_part2.hdf5
#
# Epoch 00133: loss improved from 0.28820 to 0.27807, saving model to model_part2.hdf5
#
# Epoch 00134: loss improved from 0.27807 to 0.27360, saving model to model_part2.hdf5
#
# Epoch 00135: loss improved from 0.27360 to 0.27220, saving model to model_part2.hdf5
#
# Epoch 00136: loss improved from 0.27220 to 0.26711, saving model to model_part2.hdf5
#
# Epoch 00137: loss improved from 0.26711 to 0.26087, saving model to model_part2.hdf5
#
# Epoch 00138: loss improved from 0.26087 to 0.25395, saving model to model_part2.hdf5
#
# Epoch 00139: loss improved from 0.25395 to 0.25013, saving model to model_part2.hdf5
#
# Epoch 00140: loss improved from 0.25013 to 0.24547, saving model to model_part2.hdf5
#
# Epoch 00141: loss improved from 0.24547 to 0.24294, saving model to model_part2.hdf5
#
# Epoch 00142: loss improved from 0.24294 to 0.23731, saving model to model_part2.hdf5
#
# Epoch 00143: loss did not improve from 0.23731
#
# Epoch 00144: loss improved from 0.23731 to 0.22760, saving model to model_part2.hdf5
#
# Epoch 00145: loss improved from 0.22760 to 0.22565, saving model to model_part2.hdf5
#
# Epoch 00146: loss improved from 0.22565 to 0.22102, saving model to model_part2.hdf5
#
# Epoch 00147: loss improved from 0.22102 to 0.21658, saving model to model_part2.hdf5
#
# Epoch 00148: loss did not improve from 0.21658
#
# Epoch 00149: loss improved from 0.21658 to 0.21609, saving model to model_part2.hdf5
# Testing the model
# 45/45 [==============================] - 0s 3ms/step
# ====================================================
# Percent Training Size  1
# Training the Model

# %%
plt.plot(train_sizes, accuracy)
plt.xlabel("Percent Training Size")
plt.ylabel("Accuracy")
plt.title("Percent Features vs Accuracy")
plt.show()
